# %% [markdown]
# ## 🚀 Optiver Trading Challenge: XGBoost vs LightGBM Overview 🚀
#
# ### Unveiling the Competitors: XGBoost & LightGBM 🥊
#
# In the world of machine learning, the algorithms we choose are pivotal in navigating the labyrinth of data towards robust predictions. Two titans stand out in this arena – XGBoost and LightGBM. Both have their unique strengths and are celebrated for their performance, but let's dissect their differences to understand when to use each.
#
# #### 🌿 LightGBM: The Speedster for Massive Datasets
# LightGBM, standing tall with its efficiency, is designed to sprint through massive datasets. It boasts a leaf-wise tree growth and histogram-based computing, excelling in classification, regression, and ranking tasks.
#
# ##### Advantages:
# - **Swift and Scalable**: Thanks to its histogram-based feature binning and leaf-wise growth, LightGBM is a speed demon, especially on large datasets. It converges faster and demands less memory, making it ideal for large-scale applications.
# - **Precision in Large Data**: Its distributed computing capability makes it a behemoth for handling vast amounts of high-dimensional data, ensuring accurate models even on the grandest of data stages.
# - **Memory Efficiency**: While efficient, its leaf-wise approach may use more memory compared to other gradient boosting algorithms, potentially making it a hungry beast when working with limited memory resources.
# - **Categorical Features**: LightGBM has a nifty trick up its sleeve – it can effectively handle categorical features by numerical transformation, sidestepping the need for one-hot encoding and keeping the memory usage lean.
#
# ##### Disadvantages:
# - **Thirsty for Memory**: LightGBM might demand more memory due to its leaf-wise expansion, potentially making it less ideal for memory-constrained situations.
# - **Noise Sensitive**: Its keen focus on larger gradient samples can lead to overfitting noisy data, necessitating a careful approach to data preparation and feature engineering.
# - **Categorical Feature Caveat**: Despite its prowess with numerical conversion of categorical features, LightGBM doesn't support native categorical features, often requiring additional preprocessing.
#
# #### 🌲 XGBoost: The Balanced Powerhouse
# XGBoost shines with its excellent performance and scalability. Renowned for its stellar prediction accuracy and suitability across a range of objectives and metrics, XGBoost is a force to be reckoned with in the machine learning competitions.
#
# ##### Advantages:
# - **Regularization Champ**: With its L1 and L2 regularization, XGBoost keeps overfitting in check, ensuring that models don't just memorize but generalize well.
# - **Missing Values Magician**: XGBoost can intuitively handle missing data, saving precious preprocessing time and maintaining the integrity of real-world data handling.
# - **Categorical Nuance**: Through one-hot encoding, XGBoost gives due diligence to categorical features, preserving their intricate relationships with the target variables.
#
# ##### Disadvantages:
# - **Patience Required**: Training on large datasets might test your patience as XGBoost's level-wise growth can be time and resource-intensive.
# - **Memory Considerations**: Stability comes at a cost – the level-wise method can be heavy on memory, making it a bit cumbersome for constrained environments.
#
# ### 🏁 The Verdict
# Both LightGBM and XGBoost are stellar performers with their own sets of pros and cons. Your choice might hinge on the scale of the dataset, computational resources, and the importance of model interpretability. In the end, both are capable of delivering the gold in constructing reliable and precise models.
#
# ### 🚀 Introduction to the Notebook 🚀
# Armed with the knowledge of these two algorithms, we proceed to use XGBoost in our notebook, leveraging its strengths for our prediction tasks. Follow along as we unravel the story the data tells through XGBoost's robust and precise modeling.
#
# ### Inspiration and Credits 🙌
# This notebook is a continuation from this notebook https://www.kaggle.com/code/zulqarnainali/explained-singel-model-optiver, which draws inspiration from the remarkable work of Angle, which can be found in [this Kaggle project](https://www.kaggle.com/code/lblhandsome/optiver-robust-best-single-model/notebook). Special thanks to Angle for sharing valuable insights and code.
#
# 🙏 Your time and consideration are greatly appreciated. If you find this notebook valuable, please give it a thumbs-up! 👍
#
# ## Purpose 🎯
# This notebook serves several primary purposes:
# - Load and preprocess the competition data 📁
# - Engineer pertinent features for training predictive models 🏋️‍♂️
# - Train models to predict the target variable 🧠
# - Submit predictions to the competition environment 📤
#
# ## Notebook Structure 📚
# This notebook follows a structured approach:
# 1. **Data Preparation**: We load and preprocess the competition data in this section.
# 2. **Feature Engineering**: The generation and selection of relevant features for model training are covered here.
# 3. **Model Training**: Machine learning models are trained on the prepared data.
# 4. **Prediction and Submission**: We make predictions on the test data and submit them for evaluation.
#
# ## How to Use 🛠️
# To make the most of this notebook, please adhere to these steps:
# 1. Ensure you have the competition data and environment ready.
# 2. Execute the cells in order for data preparation, feature engineering, model training, and prediction submission.
# 3. Customize and adjust the code as needed to enhance model performance or experiment with different approaches.
#
# **Note**: Be sure to replace any placeholder paths or configurations with your specific information.

# %% [markdown]
# ## 🧹 Importing necessary libraries

# %%
import gc  # Garbage collection for memory management
import os  # Operating system-related functions
import time  # Time-related functions
import warnings  # Handling warnings
from itertools import combinations  # For creating combinations of elements
from warnings import simplefilter  # Simplifying warning handling

# 📦 Importing machine learning libraries
import joblib  # For saving and loading models
import xgboost as xgb  # XGBoost gradient boosting framework
import numpy as np  # Numerical operations
import pandas as pd  # Data manipulation and analysis
from sklearn.metrics import mean_absolute_error  # Metric for evaluation
from sklearn.model_selection import KFold, TimeSeriesSplit  # Cross-validation techniques

# 🤐 Disable warnings to keep the code clean
warnings.filterwarnings("ignore")
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# 📊 Define flags and variables
is_offline = False  # Flag for online/offline mode
is_train = True  # Flag for training mode
is_infer = True  # Flag for inference mode
max_lookback = np.nan  # Maximum lookback (not specified)
split_day = 435  # Split day for time series data
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## 📊 Data Loading and Preprocessing 📊

# %% [markdown]
# **Explaination**
#
# 1. `df = pd.read_csv("/kaggle/input/optiver-trading-at-the-close/train.csv")`
#    - This line reads a CSV (Comma-Separated Values) file named "train.csv" using the Pandas library and assigns the resulting DataFrame to the variable `df`. The CSV file is expected to be located at the specified file path, "/kaggle/input/optiver-trading-at-the-close/train.csv". This line is loading a dataset from a file.
#
# 2. `df = df.dropna(subset=["target"])`
#    - This line drops (removes) rows from the DataFrame `df` where there are missing values (NaN) in the "target" column. It uses the `dropna` method with the `subset` parameter set to "target" to specify that it should check for missing values in the "target" column and remove rows that have missing values. The updated DataFrame is assigned back to the variable `df`.
#
# 3. `df.reset_index(drop=True, inplace=True)`
#    - This line resets the index of the DataFrame `df`. When data is removed from a DataFrame, the index labels may have gaps or may not be sequential. This line resets the index to be sequential, starting from 0, and the old index is dropped. The `drop=True` parameter indicates that the old index should be dropped, and `inplace=True` means that this operation modifies the DataFrame in place.
#
# 4. `df_shape = df.shape`
#    - This line calculates the shape of the DataFrame `df`, which means it returns a tuple containing the number of rows and columns in the DataFrame. The result is assigned to the variable `df_shape`.
#
# To summarize, the code reads a dataset from a CSV file, removes rows with missing values in a specific column ("target"), resets the index of the DataFrame to make it sequential, and finally, it calculates and stores the shape of the resulting DataFrame in the `df_shape` variable.

# %%
# 📂 Read the dataset from a CSV file using Pandas
df = pd.read_csv("/kaggle/input/optiver-trading-at-the-close/train.csv")

# 🧹 Remove rows with missing values in the "target" column
df = df.dropna(subset=["target"])

# 🔁 Reset the index of the DataFrame and apply the changes in place
df.reset_index(drop=True, inplace=True)

# 📏 Get the shape of the DataFrame (number of rows and columns)
df_shape = df.shape

# %% [markdown]
# ## 🚀 Memory Optimization Function with Data Type Conversion 🧹

# %% [markdown]
# **Explaination**
#
# This code defines a function `reduce_mem_usage` that is used to reduce the memory usage of a Pandas DataFrame by optimizing the data types of its columns.
#
# 1. `def reduce_mem_usage(df, verbose=0):`
#    - This line defines a function called `reduce_mem_usage` that takes two parameters: `df`, which is the input Pandas DataFrame that needs memory optimization, and `verbose` (defaulting to 0), which is a flag to control whether or not to provide memory optimization information.
#
# 2. `start_mem = df.memory_usage().sum() / 1024**2`
#    - This line calculates the initial memory usage of the input DataFrame `df` and stores it in the `start_mem` variable. It does this by using the `memory_usage()` method, which returns the memory usage of each column, and then sums these values. The result is divided by 1024^2 to convert it to megabytes.
#
# 3. The code then enters a loop that iterates through each column of the DataFrame using the `for col in df.columns:` loop.
#
# 4. Inside the loop, it checks the data type of the column using `col_type = df[col].dtype`.
#
# 5. If the column's data type is not 'object' (i.e., it's numeric), it proceeds with the optimization.
#
# 6. For integer columns:
#    - It checks the minimum and maximum values in the column (c_min and c_max).
#    - Depending on the range of values, it converts the column to the smallest integer data type that can accommodate the data while reducing memory usage. It checks for `int8`, `int16`, `int32`, and `int64` data types based on the data range.
#
# 7. For float columns:
#    - Similar to integer columns, it checks the minimum and maximum values.
#    - It converts the column to a `float32` data type if the range is within the limits of `np.finfo(np.float32)`. The `np.finfo()` function is used to get the floating-point type's limits.
#
# 8. If the column's data type is neither integer nor float and falls outside the specified ranges, it defaults to `float32`.
#
# 9. If `verbose` is set to a truthy value (e.g., 1), it provides information about memory optimization, including the initial and final memory usage, and the percentage reduction in memory usage.
#
# 10. Finally, the function returns the DataFrame with optimized memory usage.
#
# This function is useful for reducing the memory footprint of a DataFrame, especially when working with large datasets, by converting columns to the most memory-efficient data types based on the data they contain. It can help improve performance and reduce memory-related issues.

# %%
# 🧹 Function to reduce memory usage of a Pandas DataFrame
def reduce_mem_usage(df, verbose=0):
    """
    Iterate through all numeric columns of a dataframe and modify the data type
    to reduce memory usage.
    """
    
    # 📏 Calculate the initial memory usage of the DataFrame
    start_mem = df.memory_usage().sum() / 1024**2

    # 🔄 Iterate through each column in the DataFrame
    for col in df.columns:
        col_type = df[col].dtype

        # Check if the column's data type is not 'object' (i.e., numeric)
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            
            # Check if the column's data type is an integer
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                # Check if the column's data type is a float
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float32)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float32)

    # ℹ️ Provide memory optimization information if 'verbose' is True
    if verbose:
        logger.info(f"Memory usage of dataframe is {start_mem:.2f} MB")
        end_mem = df.memory_usage().sum() / 1024**2
        logger.info(f"Memory usage after optimization is: {end_mem:.2f} MB")
        decrease = 100 * (start_mem - end_mem) / start_mem
        logger.info(f"Decreased by {decrease:.2f}%")

    # 🔄 Return the DataFrame with optimized memory usage
    return df

# %% [markdown]
#  ## 🏎️Parallel Triplet Imbalance Calculation with Numba

# %% [markdown]
# **Explanation**
#
# This notebook illustrates the enhancement of financial time series analysis by leveraging the power of Numba's njit Just-In-Time compilation to calculate rolling averages and their pairwise Euclidean distances, thus creating insightful rolling features. Let's explore the components:
#
# 1. `from numba import njit, prange`
#    - This line imports `njit` for JIT compilation, enhancing execution speed, and `prange` for parallel loop processing, enabling concurrent computations.
#
# 2. `@njit(parallel=True)`
#    - Applied to our function, this decorator instructs Numba to optimize for performance, allowing for fast, parallel computations of rolling features.
#
# 3. `def compute_rolling_features(df_values, window_sizes):`
#    - Here, we define a function to compute rolling features using Numba, which accepts:
#      - `df_values`: A NumPy array of the DataFrame values, representing financial time series data.
#      - `window_sizes`: A list of window sizes for which rolling averages are computed.
#
# 4. `num_rows, num_features = df_values.shape`
#    - We determine the shape of our input array to understand the scope of our calculations.
#
# 5. `rolling_features = np.empty((num_rows, len(window_sizes) * num_features))`
#    - An empty array is initialized to hold the computed rolling averages for the different window sizes across all features.
#
# 6. We iterate over the range of window sizes to compute rolling averages for each size.
#
# 7. `for i in prange(len(window_sizes)):`
#    - This loop uses `prange` to parallelize the computation of rolling averages for different window sizes.
#
# 8. Within the loop, we use a sliding window approach to calculate the averages across each window size.
#
# 9. We then calculate pairwise Euclidean distances between the rolling average features using `np.linalg.norm`.
#
# 10. These distances provide a dynamic measure of how different rolling windows of averages compare with each other, capturing trends and volatilities in the data.
#
# 11. The computed distances are structured and returned as a new array, enriching the feature set for the machine learning model.
#
# 12. The resulting rolling features and their distances serve as an input to an XGBoost model, offering the model a nuanced view of temporal patterns and relationships in the data.
#
# 13. `calculate_rolling_features_numba` is an additional function that orchestrates the process, preparing the input data and invoking `compute_rolling_features` to generate and return a DataFrame populated with these new rolling features.

# %%
# 🏎️ Import Numba for just-in-time (JIT) compilation and parallel processing
from numba import njit, prange

# 📊 Function to compute triplet imbalance in parallel using Numba
@njit(parallel=True)
def compute_triplet_imbalance(df_values, comb_indices):
    num_rows = df_values.shape[0]
    num_combinations = len(comb_indices)
    imbalance_features = np.empty((num_rows, num_combinations))

    # 🔁 Loop through all combinations of triplets
    for i in prange(num_combinations):
        a, b, c = comb_indices[i]
        
        # 🔁 Loop through rows of the DataFrame
        for j in range(num_rows):
            max_val = max(df_values[j, a], df_values[j, b], df_values[j, c])
            min_val = min(df_values[j, a], df_values[j, b], df_values[j, c])
            mid_val = df_values[j, a] + df_values[j, b] + df_values[j, c] - min_val - max_val
            
            # 🚫 Prevent division by zero
            if mid_val == min_val:
                imbalance_features[j, i] = np.nan
            else:
                imbalance_features[j, i] = (max_val - mid_val) / (mid_val - min_val)

    return imbalance_features

# 📈 Function to calculate triplet imbalance for given price data and a DataFrame
def calculate_triplet_imbalance_numba(price, df):
    # Convert DataFrame to numpy array for Numba compatibility
    df_values = df[price].values
    comb_indices = [(price.index(a), price.index(b), price.index(c)) for a, b, c in combinations(price, 3)]

    # Calculate the triplet imbalance using the Numba-optimized function
    features_array = compute_triplet_imbalance(df_values, comb_indices)

    # Create a DataFrame from the results
    columns = [f"{a}_{b}_{c}_imb2" for a, b, c in combinations(price, 3)]
    features = pd.DataFrame(features_array, columns=columns)

    return features

@njit(fastmath=True)
def rolling_average(arr, window):
    """
    Calculate the rolling average for a 1D numpy array.
    
    Parameters:
    arr (numpy.ndarray): Input array to calculate the rolling average.
    window (int): The number of elements to consider for the moving average.
    
    Returns:
    numpy.ndarray: Array containing the rolling average values.
    """
    n = len(arr)
    result = np.empty(n)
    result[:window] = np.nan  # Padding with NaN for elements where the window is not full
    cumsum = np.cumsum(arr)

    for i in range(window, n):
        result[i] = (cumsum[i] - cumsum[i - window]) / window

    return result

@njit(parallel=True)
def compute_rolling_averages(df_values, window_sizes):
    """
    Calculate the rolling averages for multiple window sizes in parallel.
    
    Parameters:
    df_values (numpy.ndarray): 2D array of values to calculate the rolling averages.
    window_sizes (List[int]): List of window sizes for the rolling averages.
    
    Returns:
    numpy.ndarray: A 3D array containing the rolling averages for each window size.
    """
    num_rows, num_features = df_values.shape
    num_windows = len(window_sizes)
    rolling_features = np.empty((num_rows, num_features, num_windows))

    for feature_idx in prange(num_features):
        for window_idx, window in enumerate(window_sizes):
            rolling_features[:, feature_idx, window_idx] = rolling_average(df_values[:, feature_idx], window)

    return rolling_features

# %% [markdown]
# ## 📊 Feature Generation Functions 📊

# %% [markdown]
# **Explaination**
#
#
#
# 1. `imbalance_features(df)`:
#    - This function takes a DataFrame `df` as input.
#    - It calculates various features related to price and size data using Pandas' `eval` function, creating new columns in the DataFrame for each feature.
#    - It then creates pairwise price imbalance features for combinations of price columns.
#    - Next, it calculates triplet imbalance features using the Numba-optimized function `calculate_triplet_imbalance_numba`.
#    - It calculates the rolling features.
#    - Finally, it calculates additional features, including momentum, spread, intensity, pressure, market urgency, and depth pressure.
#    - It also calculates statistical aggregation features (mean, standard deviation, skewness, kurtosis) for both price and size columns.
#    - Shifted, return, and diff features are generated for specific columns.
#    - Infinite values in the DataFrame are replaced with 0.
#
# 2. `other_features(df)`:
#    - This function adds time-related and stock-related features to the DataFrame.
#    - It calculates the day of the week, seconds, and minutes from the "date_id" and "seconds_in_bucket" columns.
#    - It maps global features from a predefined dictionary to the DataFrame based on the "stock_id."
#
# 3. `generate_all_features(df)`:
#    - This function combines the features generated by the `imbalance_features` and `other_features` functions.
#    - It selects the relevant columns for feature generation, applies the `imbalance_features` function, adds time and stock-related features using the `other_features` function, and then performs garbage collection to free up memory.
#    - The function returns a DataFrame containing the generated features, excluding certain columns like "row_id," "target," "time_id," and "date_id."

# %%
# 📊 Function to generate imbalance features
def imbalance_features(df):
    # Define lists of price and size-related column names
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]

    # V1 features
    # Calculate various features using Pandas eval function
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("(ask_price + bid_price) / 2")
    df["liquidity_imbalance"] = df.eval("(bid_size-ask_size)/(bid_size+ask_size)")
    df["matched_imbalance"] = df.eval("(imbalance_size-matched_size)/(matched_size+imbalance_size)")
    df["size_imbalance"] = df.eval("bid_size / ask_size")
    
    # Create features for pairwise price imbalances
    for c in combinations(prices, 2):
        df[f"{c[0]}_{c[1]}_imb"] = df.eval(f"({c[0]} - {c[1]})/({c[0]} + {c[1]})")

    # Calculate triplet imbalance features using the Numba-optimized function
    for c in [['ask_price', 'bid_price', 'wap', 'reference_price'], sizes]:
        triplet_feature = calculate_triplet_imbalance_numba(c, df)
        df[triplet_feature.columns] = triplet_feature.values
        
    # V2 features
    # Calculate additional features
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['market_urgency'] = df['price_spread'] * df['liquidity_imbalance']
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    
    # Calculate various statistical aggregation features
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)
        
    # V3 features
    # Calculate shifted and return features for specific columns
    for col in ['matched_size', 'imbalance_size', 'reference_price', 'imbalance_buy_sell_flag']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_shift_{window}"] = df.groupby('stock_id')[col].shift(window)
            df[f"{col}_ret_{window}"] = df.groupby('stock_id')[col].pct_change(window)
    
    # V4 features - Rolling averages
    window_sizes = [4, 8, 10]  # Define your desired window sizes
    for price in prices:
        rolling_avg_features = compute_rolling_averages(df[price].values.reshape(-1, 1), window_sizes)

        # Assigning the rolling average results to the DataFrame
        for i, window in enumerate(window_sizes):
            column_name = f"{price}_rolling_avg_{window}"
            df[column_name] = rolling_avg_features[:, 0, i]

    # Patching the start-of-day values after all rolling averages are calculated
    for window in window_sizes:
        for idx, seconds in enumerate(df['seconds_in_bucket'].values):
            if seconds / 10 <= window:
                for price in prices:
                    column_name = f"{price}_rolling_avg_{window}"
                    df.at[idx, column_name] = df.at[idx, price]
    
    # Calculate diff features for specific columns
    for col in ['ask_price', 'bid_price', 'ask_size', 'bid_size']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_diff_{window}"] = df.groupby("stock_id")[col].diff(window)

    # Replace infinite values with 0
    return df.replace([np.inf, -np.inf], 0)

# 📅 Function to generate time and stock-related features
def other_features(df):
    df["dow"] = df["date_id"] % 5  # Day of the week
    df["seconds"] = df["seconds_in_bucket"] % 60  # Seconds
    df["minute"] = df["seconds_in_bucket"] // 60  # Minutes

    # Map global features to the DataFrame
    for key, value in global_stock_id_feats.items():
        df[f"global_{key}"] = df["stock_id"].map(value.to_dict())

    return df

# 🚀 Function to generate all features by combining imbalance and other features
def generate_all_features(df):
    # Select relevant columns for feature generation
    cols = [c for c in df.columns if c not in ["row_id", "time_id", "target"]]
    df = df[cols]
    
    # Generate imbalance features
    df = imbalance_features(df)
    
    # Generate time and stock-related features
    df = other_features(df)
    gc.collect()  # Perform garbage collection to free up memory
    
    # Select and return the generated features
    feature_name = [i for i in df.columns if i not in ["row_id", "target", "time_id", "date_id"]]
    
    return df[feature_name]

# %%
weights = [
    0.004, 0.001, 0.002, 0.006, 0.004, 0.004, 0.002, 0.006, 0.006, 0.002, 0.002, 0.008,
    0.006, 0.002, 0.008, 0.006, 0.002, 0.006, 0.004, 0.002, 0.004, 0.001, 0.006, 0.004,
    0.002, 0.002, 0.004, 0.002, 0.004, 0.004, 0.001, 0.001, 0.002, 0.002, 0.006, 0.004,
    0.004, 0.004, 0.006, 0.002, 0.002, 0.04 , 0.002, 0.002, 0.004, 0.04 , 0.002, 0.001,
    0.006, 0.004, 0.004, 0.006, 0.001, 0.004, 0.004, 0.002, 0.006, 0.004, 0.006, 0.004,
    0.006, 0.004, 0.002, 0.001, 0.002, 0.004, 0.002, 0.008, 0.004, 0.004, 0.002, 0.004,
    0.006, 0.002, 0.004, 0.004, 0.002, 0.004, 0.004, 0.004, 0.001, 0.002, 0.002, 0.008,
    0.02 , 0.004, 0.006, 0.002, 0.02 , 0.002, 0.002, 0.006, 0.004, 0.002, 0.001, 0.02,
    0.006, 0.001, 0.002, 0.004, 0.001, 0.002, 0.006, 0.006, 0.004, 0.006, 0.001, 0.002,
    0.004, 0.006, 0.006, 0.001, 0.04 , 0.006, 0.002, 0.004, 0.002, 0.002, 0.006, 0.002,
    0.002, 0.004, 0.006, 0.006, 0.002, 0.002, 0.008, 0.006, 0.004, 0.002, 0.006, 0.002,
    0.004, 0.006, 0.002, 0.004, 0.001, 0.004, 0.002, 0.004, 0.008, 0.006, 0.008, 0.002,
    0.004, 0.002, 0.001, 0.004, 0.004, 0.004, 0.006, 0.008, 0.004, 0.001, 0.001, 0.002,
    0.006, 0.004, 0.001, 0.002, 0.006, 0.004, 0.006, 0.008, 0.002, 0.002, 0.004, 0.002,
    0.04 , 0.002, 0.002, 0.004, 0.002, 0.002, 0.006, 0.02 , 0.004, 0.002, 0.006, 0.02,
    0.001, 0.002, 0.006, 0.004, 0.006, 0.004, 0.004, 0.004, 0.004, 0.002, 0.004, 0.04,
    0.002, 0.008, 0.002, 0.004, 0.001, 0.004, 0.006, 0.004,
]

weights = {int(k):v for k,v in enumerate(weights)}

# %% [markdown]
# ## Data Splitting

# %% [markdown]
# **Explaination**
#
# Checks whether it is running in offline or online mode and takes different actions accordingly. Here's what each part of the code does:
#
# 1. `if is_offline:`:
#    - This condition checks if the variable `is_offline` is `True`. If it is `True`, it means the code is running in offline mode.
#
# 2. In the offline mode block:
#    - The code splits the dataset into two parts: `df_train` and `df_valid` based on the value of the `split_day`. Data with "date_id" less than or equal to the `split_day` is assigned to `df_train`, while data with "date_id" greater than the `split_day` is assigned to `df_valid`.
#    - It then displays a message indicating that the code is running in offline mode and provides the shapes (number of rows and columns) of the training and validation sets using the `print` statements.
#
# 3. In the online mode block:
#    - If the code is not running in offline mode (i.e., `is_offline` is `False`), it means it's running in online mode.
#    - In online mode, the entire dataset is used for training, and the entire dataset is assigned to `df_train`.
#    - It displays a message indicating that the code is running in online mode using the `print` statement.
#
# The purpose of distinguishing between offline and online modes is often related to the context in which the code is used. In offline mode, you typically have historical data and can perform tasks like data splitting for training and validation, while in online mode, you might be working with real-time data and use the entire dataset for training. The choice of mode can impact the preprocessing and analysis steps that follow in the code.

# %%
# Check if the code is running in offline or online mode
if is_offline:
    # In offline mode, split the data into training and validation sets based on the split_day
    df_train = df[df["date_id"] <= split_day]
    df_valid = df[df["date_id"] > split_day]
    
    # Display a message indicating offline mode and the shapes of the training and validation sets
    print("Offline mode")
    print(f"train : {df_train.shape}, valid : {df_valid.shape}")
else:
    # In online mode, use the entire dataset for training
    df_train = df
    
    # Display a message indicating online mode
    print("Online mode")
# Out:
# Online mode

# %% [markdown]
# **Explaination**
#
#
#
# 1. `if is_train:`
#    - This condition checks if the variable `is_train` is `True`. If it is `True`, it means that the code is being executed in a training context.
#
# 2. Inside the `if is_train:` block:
#    - A dictionary named `global_stock_id_feats` is created. This dictionary contains various statistical summary features calculated for each stock_id. These features include the median, standard deviation, and range of bid sizes and ask sizes, as well as bid prices and ask prices. These statistics are computed based on the training data (`df_train`) using Pandas' `groupby` and aggregation functions.
#
# 3. The code checks if the execution mode is offline (`is_offline`) by further nested conditions.
#    - If it is offline (`is_offline` is `True`):
#      - It generates features for the training set (`df_train`) using the `generate_all_features` function.
#      - It prints a message indicating that the process of building the training features is finished.
#      - It generates features for the validation set (`df_valid`) using the `generate_all_features` function.
#      - It prints a message indicating that the process of building the validation features is finished.
#      - It reduces memory usage of the validation features using the `reduce_mem_usage` function.
#
#    - If it is not in offline mode (i.e., online mode):
#      - It generates features for the training set (`df_train`) using the `generate_all_features` function.
#      - It prints a message indicating that the process of building online training features is finished.
#
# 4. After generating features, it reduces memory usage of the training features (`df_train_feats`) using the `reduce_mem_usage` function. This is done to optimize memory consumption and improve performance.
#
# The code's purpose is to prepare and optimize the feature set for training, considering whether it is in offline or online mode and whether it's part of the training process. The generated features and memory optimization are important steps in machine learning workflows, as they impact the training process and the model's efficiency.

# %%
if is_train:
    global_stock_id_feats = {
        "median_size": df_train.groupby("stock_id")["bid_size"].median() + df_train.groupby("stock_id")["ask_size"].median(),
        "std_size": df_train.groupby("stock_id")["bid_size"].std() + df_train.groupby("stock_id")["ask_size"].std(),
        "ptp_size": df_train.groupby("stock_id")["bid_size"].max() - df_train.groupby("stock_id")["bid_size"].min(),
        "median_price": df_train.groupby("stock_id")["bid_price"].median() + df_train.groupby("stock_id")["ask_price"].median(),
        "std_price": df_train.groupby("stock_id")["bid_price"].std() + df_train.groupby("stock_id")["ask_price"].std(),
        "ptp_price": df_train.groupby("stock_id")["bid_price"].max() - df_train.groupby("stock_id")["ask_price"].min(),
    }

# %%
if is_train:
    if is_offline:
        df_train_feats = generate_all_features(df_train)
        print("Build Train Feats Finished.")
        df_valid_feats = generate_all_features(df_valid)
        print("Build Valid Feats Finished.")
        df_valid_feats = reduce_mem_usage(df_valid_feats)
    else:
        df_train_feats = generate_all_features(df_train)
        print("Build Online Train Feats Finished.")

    df_train_feats = reduce_mem_usage(df_train_feats)
# Out:
# Build Online Train Feats Finished.

# %% [markdown]
# ### Training and Evaluation with XGBoost
#
# **Explanation**
#
# The code block outlined below is tasked with training an XGBoost model, provided the `is_train` flag is set to `True`, indicating a training scenario. Should the offline mode be active, the block will also handle model inference and performance assessment.
#
# 1. **Training Condition (`if is_train:`):**
#    - This conditional statement confirms whether the code execution is meant for model training by checking the `is_train` flag.
#
# 2. **Feature Preparation:**
#    - The list of feature names used for the model is retrieved from the training feature set (`df_train_feats`), under the training condition.
#
# 3. **XGBoost Parameters:**
#    - Parameters for the XGBoost model are defined, outlining crucial hyperparameters which dictate the model's performance, such as the objective function, booster type, number of estimators, max depth, subsampling, learning rate, and tree method for GPU acceleration, among others.
#    - The count of features being used is logged, ensuring transparency in the model's input dimensions.
#
# 4. **Offline Data Split:**
#    - An offline data split is created using a mask (`offline_split`) to segregate the dataset based on a predefined date (`split_day - 45`). This split aids in constructing offline training and validation datasets.
#    - Separate DataFrames for training and validation sets, both features and targets, are instantiated for offline training.
#
# 5. **Train XGBoost Model:**
#    - An XGBoost Regressor model (`xgb_model`) is initialized with the set parameters and trained using the offline training feature set and its corresponding target.
#    - Early stopping and evaluation metrics are set to monitor and halt the training when no improvement is observed in validation scores.
#
# 6. **Memory Management:**
#    - Post-training, memory cleanup is initiated to free resources by removing variables related to training data and invoking garbage collection.
#
# 7. **Inference Setup:**
#    - The full training dataset's target variable (`df_train_target`) is delineated, and the script proceeds to fine-tune the model for inference purposes.
#    - An inference model (`infer_model`) is cloned from the primary model with adjustments made to the number of estimators as per the early stopping round's outcome.
#
# 8. **Offline Evaluation (when `is_offline` is `True`):**
#    - In offline mode, the inference model's performance is benchmarked on the validation data (`df_valid_feats`). Predictions are evaluated against actual values using mean absolute error (`mean_absolute_error`).
#    - The evaluation score is presented, offering insight into the model's accuracy in an offline setting.
#
# This framework ensures a robust model training and evaluation process, emphasizing early stopping and estimator adjustment for optimal performance, complemented by effective resource management practices.

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
import numpy as np
import gc

# Define is_gpu_enabled
is_gpu_enabled = True

if is_train:
    feature_name = list(df_train_feats.columns)
    print(f"Feature length = {len(feature_name)}")

    # Split data for offline training
    offline_split = df_train['date_id'] > (split_day - 45)
    X_offline_train = df_train_feats[~offline_split]
    X_offline_valid = df_train_feats[offline_split]
    y_offline_train = df_train['target'][~offline_split]
    y_offline_valid = df_train['target'][offline_split]

    print("Valid Model Training.")

    # Initialize the XGBRegressor with desired hyperparameters
    model = XGBRegressor(
        objective='reg:squarederror',
        tree_method='gpu_hist' if is_gpu_enabled else 'auto',
        max_depth=8,
        subsample=0.6,
        colsample_bytree=0.5,
        learning_rate=0.01,
        reg_lambda=1,
        reg_alpha=0.5,
        n_estimators=3500,
        random_state=42,
        verbosity=0
    )

    # Fit the model with early stopping
    model.fit(
        X_offline_train[feature_name], y_offline_train,
        eval_set=[(X_offline_train[feature_name], y_offline_train),
                  (X_offline_valid[feature_name], y_offline_valid)],
        eval_metric='mae',
        early_stopping_rounds=100,
        verbose=True
    )

    # Cleanup to free memory
    del X_offline_train, X_offline_valid, y_offline_train, y_offline_valid
    gc.collect()

    # Inference
    print("Infer Model Training.")
    X_train = df_train_feats[feature_name]
    y_train = df_train['target']

    # Retrain the model on the full dataset with the optimal number of trees
    optimal_n_estimators = model.best_iteration + 1 if model.best_iteration else 3000

    infer_model = XGBRegressor(
        objective='reg:squarederror',
        tree_method='gpu_hist' if is_gpu_enabled else 'auto',
        max_depth=8,
        subsample=0.6,
        colsample_bytree=0.5,
        learning_rate=0.01,
        reg_lambda=1,
        reg_alpha=0.5,
        n_estimators=optimal_n_estimators,
        random_state=42,
        verbosity=0
    )

    # Fit the model on the full training data
    infer_model.fit(X_train, y_train, verbose=True)

    if is_offline:
        # Offline predictions and evaluation
        X_valid = df_valid_feats[feature_name]
        y_valid = df_valid['target']
        offline_predictions = infer_model.predict(X_valid)
        offline_score = mean_absolute_error(offline_predictions, y_valid)
        print(f"Offline Score: {np.round(offline_score, 4)}")
# Out:
# Feature length = 130
# Valid Model Training.
# [0]	validation_0-mae:6.51505	validation_1-mae:6.03918
# [1]	validation_0-mae:6.51240	validation_1-mae:6.03717
# [2]	validation_0-mae:6.50974	validation_1-mae:6.03512
# [3]	validation_0-mae:6.50719	validation_1-mae:6.03323
# [4]	validation_0-mae:6.50468	validation_1-mae:6.03134
# [5]	validation_0-mae:6.50214	validation_1-mae:6.02945
# [6]	validation_0-mae:6.49970	validation_1-mae:6.02762
# [7]	validation_0-mae:6.49722	validation_1-mae:6.02575
# [8]	validation_0-mae:6.49479	validation_1-mae:6.02392
# [9]	validation_0-mae:6.49248	validation_1-mae:6.02216
# [10]	validation_0-mae:6.49018	validation_1-mae:6.02044
# [11]	validation_0-mae:6.48791	validation_1-mae:6.01869
# [12]	validation_0-mae:6.48572	validation_1-mae:6.01707
# [13]	validation_0-mae:6.48353	validation_1-mae:6.01548
# [14]	validation_0-mae:6.48142	validation_1-mae:6.01390
# [15]	validation_0-mae:6.47931	validation_1-mae:6.01231
# [16]	validation_0-mae:6.47726	validation_1-mae:6.01079
# [17]	validation_0-mae:6.47518	validation_1-mae:6.00923
# [18]	validation_0-mae:6.47319	validation_1-mae:6.00768
# [19]	validation_0-mae:6.47124	validation_1-mae:6.00627
# [20]	validation_0-mae:6.46944	validation_1-mae:6.00488
# [21]	validation_0-mae:6.46754	validation_1-mae:6.00350
# [22]	validation_0-mae:6.46569	validation_1-mae:6.00212
# [23]	validation_0-mae:6.46383	validation_1-mae:6.00073
# [24]	validation_0-mae:6.46199	validation_1-mae:5.99937
# [25]	validation_0-mae:6.46022	validation_1-mae:5.99805
# [26]	validation_0-mae:6.45848	validation_1-mae:5.99677
# [27]	validation_0-mae:6.45674	validation_1-mae:5.99551
# [28]	validation_0-mae:6.45507	validation_1-mae:5.99428
# [29]	validation_0-mae:6.45342	validation_1-mae:5.99309
# [30]	validation_0-mae:6.45174	validation_1-mae:5.99188
# [31]	validation_0-mae:6.45018	validation_1-mae:5.99065
# [32]	validation_0-mae:6.44862	validation_1-mae:5.98956
# [33]	validation_0-mae:6.44709	validation_1-mae:5.98844
# [34]	validation_0-mae:6.44563	validation_1-mae:5.98734
# [35]	validation_0-mae:6.44415	validation_1-mae:5.98623
# [36]	validation_0-mae:6.44274	validation_1-mae:5.98522
# [37]	validation_0-mae:6.44133	validation_1-mae:5.98419
# [38]	validation_0-mae:6.43991	validation_1-mae:5.98315
# [39]	validation_0-mae:6.43850	validation_1-mae:5.98211
# [40]	validation_0-mae:6.43715	validation_1-mae:5.98113
# [41]	validation_0-mae:6.43580	validation_1-mae:5.98020
# [42]	validation_0-mae:6.43451	validation_1-mae:5.97925
# [43]	validation_0-mae:6.43316	validation_1-mae:5.97828
# [44]	validation_0-mae:6.43190	validation_1-mae:5.97739
# [45]	validation_0-mae:6.43064	validation_1-mae:5.97651
# [46]	validation_0-mae:6.42939	validation_1-mae:5.97562
# [47]	validation_0-mae:6.42816	validation_1-mae:5.97474
# [48]	validation_0-mae:6.42697	validation_1-mae:5.97394
# [49]	validation_0-mae:6.42581	validation_1-mae:5.97315
# [50]	validation_0-mae:6.42467	validation_1-mae:5.97231
# [51]	validation_0-mae:6.42355	validation_1-mae:5.97154
# [52]	validation_0-mae:6.42244	validation_1-mae:5.97075
# [53]	validation_0-mae:6.42129	validation_1-mae:5.96995
# [54]	validation_0-mae:6.42017	validation_1-mae:5.96916
# [55]	validation_0-mae:6.41908	validation_1-mae:5.96838
# [56]	validation_0-mae:6.41804	validation_1-mae:5.96767
# [57]	validation_0-mae:6.41704	validation_1-mae:5.96698
# [58]	validation_0-mae:6.41605	validation_1-mae:5.96628
# [59]	validation_0-mae:6.41508	validation_1-mae:5.96563
# [60]	validation_0-mae:6.41408	validation_1-mae:5.96496
# [61]	validation_0-mae:6.41313	validation_1-mae:5.96432
# [62]	validation_0-mae:6.41214	validation_1-mae:5.96367
# [63]	validation_0-mae:6.41119	validation_1-mae:5.96305
# [64]	validation_0-mae:6.41025	validation_1-mae:5.96237
# [65]	validation_0-mae:6.40934	validation_1-mae:5.96178
# [66]	validation_0-mae:6.40841	validation_1-mae:5.96116
# [67]	validation_0-mae:6.40760	validation_1-mae:5.96063
# [68]	validation_0-mae:6.40680	validation_1-mae:5.96012
# [69]	validation_0-mae:6.40598	validation_1-mae:5.95958
# [70]	validation_0-mae:6.40516	validation_1-mae:5.95903
# [71]	validation_0-mae:6.40434	validation_1-mae:5.95846
# [72]	validation_0-mae:6.40349	validation_1-mae:5.95784
# [73]	validation_0-mae:6.40272	validation_1-mae:5.95735
# [74]	validation_0-mae:6.40191	validation_1-mae:5.95680
# [75]	validation_0-mae:6.40118	validation_1-mae:5.95630
# [76]	validation_0-mae:6.40044	validation_1-mae:5.95582
# [77]	validation_0-mae:6.39973	validation_1-mae:5.95535
# [78]	validation_0-mae:6.39894	validation_1-mae:5.95483
# [79]	validation_0-mae:6.39821	validation_1-mae:5.95429
# [80]	validation_0-mae:6.39747	validation_1-mae:5.95381
# [81]	validation_0-mae:6.39673	validation_1-mae:5.95331
# [82]	validation_0-mae:6.39603	validation_1-mae:5.95284
# [83]	validation_0-mae:6.39532	validation_1-mae:5.95235
# [84]	validation_0-mae:6.39462	validation_1-mae:5.95194
# [85]	validation_0-mae:6.39399	validation_1-mae:5.95155
# [86]	validation_0-mae:6.39330	validation_1-mae:5.95107
# [87]	validation_0-mae:6.39262	validation_1-mae:5.95063
# [88]	validation_0-mae:6.39201	validation_1-mae:5.95024
# [89]	validation_0-mae:6.39132	validation_1-mae:5.94975
# [90]	validation_0-mae:6.39069	validation_1-mae:5.94934
# [91]	validation_0-mae:6.39005	validation_1-mae:5.94892
# [92]	validation_0-mae:6.38943	validation_1-mae:5.94852
# [93]	validation_0-mae:6.38881	validation_1-mae:5.94811
# [94]	validation_0-mae:6.38817	validation_1-mae:5.94763
# [95]	validation_0-mae:6.38756	validation_1-mae:5.94723
# [96]	validation_0-mae:6.38700	validation_1-mae:5.94688
# [97]	validation_0-mae:6.38641	validation_1-mae:5.94650
# [98]	validation_0-mae:6.38581	validation_1-mae:5.94612
# [99]	validation_0-mae:6.38522	validation_1-mae:5.94568
# [100]	validation_0-mae:6.38467	validation_1-mae:5.94534
# [101]	validation_0-mae:6.38412	validation_1-mae:5.94500
# [102]	validation_0-mae:6.38356	validation_1-mae:5.94468
# [103]	validation_0-mae:6.38301	validation_1-mae:5.94438
# [104]	validation_0-mae:6.38249	validation_1-mae:5.94406
# [105]	validation_0-mae:6.38196	validation_1-mae:5.94376
# [106]	validation_0-mae:6.38145	validation_1-mae:5.94349
# [107]	validation_0-mae:6.38091	validation_1-mae:5.94312
# [108]	validation_0-mae:6.38041	validation_1-mae:5.94280
# [109]	validation_0-mae:6.37993	validation_1-mae:5.94247
# [110]	validation_0-mae:6.37944	validation_1-mae:5.94218
# [111]	validation_0-mae:6.37899	validation_1-mae:5.94194
# [112]	validation_0-mae:6.37851	validation_1-mae:5.94162
# [113]	validation_0-mae:6.37803	validation_1-mae:5.94132
# [114]	validation_0-mae:6.37756	validation_1-mae:5.94103
# [115]	validation_0-mae:6.37713	validation_1-mae:5.94081
# [116]	validation_0-mae:6.37667	validation_1-mae:5.94054
# [117]	validation_0-mae:6.37620	validation_1-mae:5.94027
# [118]	validation_0-mae:6.37577	validation_1-mae:5.93999
# [119]	validation_0-mae:6.37530	validation_1-mae:5.93964
# [120]	validation_0-mae:6.37487	validation_1-mae:5.93938
# [121]	validation_0-mae:6.37446	validation_1-mae:5.93917
# [122]	validation_0-mae:6.37400	validation_1-mae:5.93888
# [123]	validation_0-mae:6.37356	validation_1-mae:5.93858
# [124]	validation_0-mae:6.37312	validation_1-mae:5.93828
# [125]	validation_0-mae:6.37271	validation_1-mae:5.93805
# [126]	validation_0-mae:6.37230	validation_1-mae:5.93785
# [127]	validation_0-mae:6.37191	validation_1-mae:5.93767
# [128]	validation_0-mae:6.37153	validation_1-mae:5.93745
# [129]	validation_0-mae:6.37114	validation_1-mae:5.93725
# [130]	validation_0-mae:6.37069	validation_1-mae:5.93696
# [131]	validation_0-mae:6.37029	validation_1-mae:5.93672
# [132]	validation_0-mae:6.36988	validation_1-mae:5.93644
# [133]	validation_0-mae:6.36952	validation_1-mae:5.93623
# [134]	validation_0-mae:6.36915	validation_1-mae:5.93603
# [135]	validation_0-mae:6.36881	validation_1-mae:5.93585
# [136]	validation_0-mae:6.36845	validation_1-mae:5.93569
# [137]	validation_0-mae:6.36806	validation_1-mae:5.93542
# [138]	validation_0-mae:6.36772	validation_1-mae:5.93529
# [139]	validation_0-mae:6.36737	validation_1-mae:5.93509
# [140]	validation_0-mae:6.36707	validation_1-mae:5.93492
# [141]	validation_0-mae:6.36673	validation_1-mae:5.93471
# [142]	validation_0-mae:6.36644	validation_1-mae:5.93460
# [143]	validation_0-mae:6.36607	validation_1-mae:5.93436
# [144]	validation_0-mae:6.36573	validation_1-mae:5.93416
# [145]	validation_0-mae:6.36538	validation_1-mae:5.93397
# [146]	validation_0-mae:6.36508	validation_1-mae:5.93382
# [147]	validation_0-mae:6.36477	validation_1-mae:5.93368
# [148]	validation_0-mae:6.36436	validation_1-mae:5.93343
# [149]	validation_0-mae:6.36401	validation_1-mae:5.93319
# [150]	validation_0-mae:6.36370	validation_1-mae:5.93302
# [151]	validation_0-mae:6.36338	validation_1-mae:5.93286
# [152]	validation_0-mae:6.36306	validation_1-mae:5.93271
# [153]	validation_0-mae:6.36277	validation_1-mae:5.93258
# [154]	validation_0-mae:6.36248	validation_1-mae:5.93243
# [155]	validation_0-mae:6.36220	validation_1-mae:5.93230
# [156]	validation_0-mae:6.36189	validation_1-mae:5.93215
# [157]	validation_0-mae:6.36159	validation_1-mae:5.93197
# [158]	validation_0-mae:6.36129	validation_1-mae:5.93180
# [159]	validation_0-mae:6.36102	validation_1-mae:5.93169
# [160]	validation_0-mae:6.36078	validation_1-mae:5.93158
# [161]	validation_0-mae:6.36047	validation_1-mae:5.93139
# [162]	validation_0-mae:6.36019	validation_1-mae:5.93124
# [163]	validation_0-mae:6.35994	validation_1-mae:5.93113
# [164]	validation_0-mae:6.35966	validation_1-mae:5.93097
# [165]	validation_0-mae:6.35937	validation_1-mae:5.93088
# [166]	validation_0-mae:6.35907	validation_1-mae:5.93074
# [167]	validation_0-mae:6.35882	validation_1-mae:5.93061
# [168]	validation_0-mae:6.35856	validation_1-mae:5.93050
# [169]	validation_0-mae:6.35830	validation_1-mae:5.93037
# [170]	validation_0-mae:6.35802	validation_1-mae:5.93018
# [171]	validation_0-mae:6.35774	validation_1-mae:5.93004
# [172]	validation_0-mae:6.35744	validation_1-mae:5.92988
# [173]	validation_0-mae:6.35717	validation_1-mae:5.92974
# [174]	validation_0-mae:6.35693	validation_1-mae:5.92963
# [175]	validation_0-mae:6.35669	validation_1-mae:5.92955
# [176]	validation_0-mae:6.35644	validation_1-mae:5.92943
# [177]	validation_0-mae:6.35620	validation_1-mae:5.92930
# [178]	validation_0-mae:6.35597	validation_1-mae:5.92925
# [179]	validation_0-mae:6.35572	validation_1-mae:5.92912
# [180]	validation_0-mae:6.35546	validation_1-mae:5.92894
# [181]	validation_0-mae:6.35517	validation_1-mae:5.92871
# [182]	validation_0-mae:6.35493	validation_1-mae:5.92863
# [183]	validation_0-mae:6.35472	validation_1-mae:5.92853
# [184]	validation_0-mae:6.35448	validation_1-mae:5.92841
# [185]	validation_0-mae:6.35422	validation_1-mae:5.92827
# [186]	validation_0-mae:6.35393	validation_1-mae:5.92814
# [187]	validation_0-mae:6.35367	validation_1-mae:5.92803
# [188]	validation_0-mae:6.35341	validation_1-mae:5.92791
# [189]	validation_0-mae:6.35318	validation_1-mae:5.92780
# [190]	validation_0-mae:6.35301	validation_1-mae:5.92778
# [191]	validation_0-mae:6.35280	validation_1-mae:5.92769
# [192]	validation_0-mae:6.35255	validation_1-mae:5.92756
# [193]	validation_0-mae:6.35233	validation_1-mae:5.92745
# [194]	validation_0-mae:6.35211	validation_1-mae:5.92734
# [195]	validation_0-mae:6.35182	validation_1-mae:5.92715
# [196]	validation_0-mae:6.35162	validation_1-mae:5.92706
# [197]	validation_0-mae:6.35140	validation_1-mae:5.92698
# [198]	validation_0-mae:6.35117	validation_1-mae:5.92688
# [199]	validation_0-mae:6.35094	validation_1-mae:5.92676
# [200]	validation_0-mae:6.35074	validation_1-mae:5.92668
# [201]	validation_0-mae:6.35056	validation_1-mae:5.92660
# [202]	validation_0-mae:6.35028	validation_1-mae:5.92639
# [203]	validation_0-mae:6.35006	validation_1-mae:5.92631
# [204]	validation_0-mae:6.34978	validation_1-mae:5.92618
# [205]	validation_0-mae:6.34953	validation_1-mae:5.92601
# [206]	validation_0-mae:6.34931	validation_1-mae:5.92591
# [207]	validation_0-mae:6.34909	validation_1-mae:5.92580
# [208]	validation_0-mae:6.34885	validation_1-mae:5.92563
# [209]	validation_0-mae:6.34865	validation_1-mae:5.92555
# [210]	validation_0-mae:6.34849	validation_1-mae:5.92550
# [211]	validation_0-mae:6.34827	validation_1-mae:5.92537
# [212]	validation_0-mae:6.34811	validation_1-mae:5.92532
# [213]	validation_0-mae:6.34791	validation_1-mae:5.92530
# [214]	validation_0-mae:6.34772	validation_1-mae:5.92521
# [215]	validation_0-mae:6.34753	validation_1-mae:5.92513
# [216]	validation_0-mae:6.34735	validation_1-mae:5.92510
# [217]	validation_0-mae:6.34716	validation_1-mae:5.92502
# [218]	validation_0-mae:6.34683	validation_1-mae:5.92476
# [219]	validation_0-mae:6.34654	validation_1-mae:5.92453
# [220]	validation_0-mae:6.34637	validation_1-mae:5.92449
# [221]	validation_0-mae:6.34613	validation_1-mae:5.92437
# [222]	validation_0-mae:6.34594	validation_1-mae:5.92433
# [223]	validation_0-mae:6.34576	validation_1-mae:5.92428
# [224]	validation_0-mae:6.34556	validation_1-mae:5.92419
# [225]	validation_0-mae:6.34541	validation_1-mae:5.92417
# [226]	validation_0-mae:6.34525	validation_1-mae:5.92415
# [227]	validation_0-mae:6.34500	validation_1-mae:5.92395
# [228]	validation_0-mae:6.34475	validation_1-mae:5.92380
# [229]	validation_0-mae:6.34457	validation_1-mae:5.92374
# [230]	validation_0-mae:6.34442	validation_1-mae:5.92368
# [231]	validation_0-mae:6.34425	validation_1-mae:5.92362
# [232]	validation_0-mae:6.34409	validation_1-mae:5.92359
# [233]	validation_0-mae:6.34390	validation_1-mae:5.92347
# [234]	validation_0-mae:6.34372	validation_1-mae:5.92341
# [235]	validation_0-mae:6.34356	validation_1-mae:5.92334
# [236]	validation_0-mae:6.34342	validation_1-mae:5.92333
# [237]	validation_0-mae:6.34321	validation_1-mae:5.92324
# [238]	validation_0-mae:6.34302	validation_1-mae:5.92311
# [239]	validation_0-mae:6.34286	validation_1-mae:5.92306
# [240]	validation_0-mae:6.34263	validation_1-mae:5.92290
# [241]	validation_0-mae:6.34243	validation_1-mae:5.92281
# [242]	validation_0-mae:6.34221	validation_1-mae:5.92271
# [243]	validation_0-mae:6.34196	validation_1-mae:5.92253
# [244]	validation_0-mae:6.34179	validation_1-mae:5.92249
# [245]	validation_0-mae:6.34165	validation_1-mae:5.92245
# [246]	validation_0-mae:6.34142	validation_1-mae:5.92231
# [247]	validation_0-mae:6.34127	validation_1-mae:5.92228
# [248]	validation_0-mae:6.34110	validation_1-mae:5.92221
# [249]	validation_0-mae:6.34091	validation_1-mae:5.92212
# [250]	validation_0-mae:6.34074	validation_1-mae:5.92209
# [251]	validation_0-mae:6.34054	validation_1-mae:5.92196
# [252]	validation_0-mae:6.34039	validation_1-mae:5.92192
# [253]	validation_0-mae:6.34010	validation_1-mae:5.92173
# [254]	validation_0-mae:6.33992	validation_1-mae:5.92168
# [255]	validation_0-mae:6.33977	validation_1-mae:5.92164
# [256]	validation_0-mae:6.33958	validation_1-mae:5.92155
# [257]	validation_0-mae:6.33936	validation_1-mae:5.92142
# [258]	validation_0-mae:6.33914	validation_1-mae:5.92134
# [259]	validation_0-mae:6.33895	validation_1-mae:5.92124
# [260]	validation_0-mae:6.33879	validation_1-mae:5.92117
# [261]	validation_0-mae:6.33863	validation_1-mae:5.92111
# [262]	validation_0-mae:6.33845	validation_1-mae:5.92102
# [263]	validation_0-mae:6.33828	validation_1-mae:5.92101
# [264]	validation_0-mae:6.33815	validation_1-mae:5.92099
# [265]	validation_0-mae:6.33797	validation_1-mae:5.92087
# [266]	validation_0-mae:6.33779	validation_1-mae:5.92080
# [267]	validation_0-mae:6.33764	validation_1-mae:5.92073
# [268]	validation_0-mae:6.33750	validation_1-mae:5.92070
# [269]	validation_0-mae:6.33736	validation_1-mae:5.92068
# [270]	validation_0-mae:6.33720	validation_1-mae:5.92067
# [271]	validation_0-mae:6.33702	validation_1-mae:5.92058
# [272]	validation_0-mae:6.33679	validation_1-mae:5.92046
# [273]	validation_0-mae:6.33665	validation_1-mae:5.92042
# [274]	validation_0-mae:6.33644	validation_1-mae:5.92029
# [275]	validation_0-mae:6.33631	validation_1-mae:5.92027
# [276]	validation_0-mae:6.33613	validation_1-mae:5.92017
# [277]	validation_0-mae:6.33599	validation_1-mae:5.92014
# [278]	validation_0-mae:6.33583	validation_1-mae:5.92009
# [279]	validation_0-mae:6.33571	validation_1-mae:5.92009
# [280]	validation_0-mae:6.33558	validation_1-mae:5.92005
# [281]	validation_0-mae:6.33541	validation_1-mae:5.91998
# [282]	validation_0-mae:6.33530	validation_1-mae:5.91995
# [283]	validation_0-mae:6.33516	validation_1-mae:5.91991
# [284]	validation_0-mae:6.33498	validation_1-mae:5.91984
# [285]	validation_0-mae:6.33479	validation_1-mae:5.91973
# [286]	validation_0-mae:6.33465	validation_1-mae:5.91967
# [287]	validation_0-mae:6.33446	validation_1-mae:5.91957
# [288]	validation_0-mae:6.33432	validation_1-mae:5.91954
# [289]	validation_0-mae:6.33420	validation_1-mae:5.91951
# [290]	validation_0-mae:6.33402	validation_1-mae:5.91945
# [291]	validation_0-mae:6.33391	validation_1-mae:5.91946
# [292]	validation_0-mae:6.33375	validation_1-mae:5.91935
# [293]	validation_0-mae:6.33363	validation_1-mae:5.91934
# [294]	validation_0-mae:6.33351	validation_1-mae:5.91932
# [295]	validation_0-mae:6.33339	validation_1-mae:5.91928
# [296]	validation_0-mae:6.33317	validation_1-mae:5.91913
# [297]	validation_0-mae:6.33301	validation_1-mae:5.91906
# [298]	validation_0-mae:6.33286	validation_1-mae:5.91900
# [299]	validation_0-mae:6.33271	validation_1-mae:5.91894
# [300]	validation_0-mae:6.33257	validation_1-mae:5.91890
# [301]	validation_0-mae:6.33240	validation_1-mae:5.91889
# [302]	validation_0-mae:6.33226	validation_1-mae:5.91881
# [303]	validation_0-mae:6.33212	validation_1-mae:5.91877
# [304]	validation_0-mae:6.33195	validation_1-mae:5.91867
# [305]	validation_0-mae:6.33179	validation_1-mae:5.91858
# [306]	validation_0-mae:6.33152	validation_1-mae:5.91838
# [307]	validation_0-mae:6.33137	validation_1-mae:5.91831
# [308]	validation_0-mae:6.33118	validation_1-mae:5.91822
# [309]	validation_0-mae:6.33096	validation_1-mae:5.91805
# [310]	validation_0-mae:6.33084	validation_1-mae:5.91802
# [311]	validation_0-mae:6.33071	validation_1-mae:5.91800
# [312]	validation_0-mae:6.33057	validation_1-mae:5.91795
# [313]	validation_0-mae:6.33044	validation_1-mae:5.91794
# [314]	validation_0-mae:6.33030	validation_1-mae:5.91790
# [315]	validation_0-mae:6.33006	validation_1-mae:5.91771
# [316]	validation_0-mae:6.32990	validation_1-mae:5.91768
# [317]	validation_0-mae:6.32970	validation_1-mae:5.91757
# [318]	validation_0-mae:6.32949	validation_1-mae:5.91745
# [319]	validation_0-mae:6.32934	validation_1-mae:5.91742
# [320]	validation_0-mae:6.32924	validation_1-mae:5.91741
# [321]	validation_0-mae:6.32912	validation_1-mae:5.91742
# [322]	validation_0-mae:6.32899	validation_1-mae:5.91740
# [323]	validation_0-mae:6.32883	validation_1-mae:5.91734
# [324]	validation_0-mae:6.32871	validation_1-mae:5.91733
# [325]	validation_0-mae:6.32854	validation_1-mae:5.91723
# [326]	validation_0-mae:6.32837	validation_1-mae:5.91712
# [327]	validation_0-mae:6.32823	validation_1-mae:5.91709
# [328]	validation_0-mae:6.32802	validation_1-mae:5.91696
# [329]	validation_0-mae:6.32787	validation_1-mae:5.91690
# [330]	validation_0-mae:6.32769	validation_1-mae:5.91680
# [331]	validation_0-mae:6.32759	validation_1-mae:5.91679
# [332]	validation_0-mae:6.32744	validation_1-mae:5.91675
# [333]	validation_0-mae:6.32721	validation_1-mae:5.91661
# [334]	validation_0-mae:6.32706	validation_1-mae:5.91655
# [335]	validation_0-mae:6.32691	validation_1-mae:5.91647
# [336]	validation_0-mae:6.32679	validation_1-mae:5.91646
# [337]	validation_0-mae:6.32665	validation_1-mae:5.91643
# [338]	validation_0-mae:6.32654	validation_1-mae:5.91641
# [339]	validation_0-mae:6.32639	validation_1-mae:5.91632
# [340]	validation_0-mae:6.32628	validation_1-mae:5.91631
# [341]	validation_0-mae:6.32615	validation_1-mae:5.91629
# [342]	validation_0-mae:6.32601	validation_1-mae:5.91627
# [343]	validation_0-mae:6.32584	validation_1-mae:5.91621
# [344]	validation_0-mae:6.32567	validation_1-mae:5.91611
# [345]	validation_0-mae:6.32558	validation_1-mae:5.91610
# [346]	validation_0-mae:6.32534	validation_1-mae:5.91598
# [347]	validation_0-mae:6.32518	validation_1-mae:5.91595
# [348]	validation_0-mae:6.32507	validation_1-mae:5.91594
# [349]	validation_0-mae:6.32494	validation_1-mae:5.91593
# [350]	validation_0-mae:6.32479	validation_1-mae:5.91588
# [351]	validation_0-mae:6.32452	validation_1-mae:5.91573
# [352]	validation_0-mae:6.32440	validation_1-mae:5.91570
# [353]	validation_0-mae:6.32429	validation_1-mae:5.91570
# [354]	validation_0-mae:6.32416	validation_1-mae:5.91565
# [355]	validation_0-mae:6.32398	validation_1-mae:5.91555
# [356]	validation_0-mae:6.32384	validation_1-mae:5.91551
# [357]	validation_0-mae:6.32366	validation_1-mae:5.91537
# [358]	validation_0-mae:6.32351	validation_1-mae:5.91532
# [359]	validation_0-mae:6.32331	validation_1-mae:5.91519
# [360]	validation_0-mae:6.32313	validation_1-mae:5.91511
# [361]	validation_0-mae:6.32301	validation_1-mae:5.91510
# [362]	validation_0-mae:6.32289	validation_1-mae:5.91507
# [363]	validation_0-mae:6.32275	validation_1-mae:5.91504
# [364]	validation_0-mae:6.32266	validation_1-mae:5.91501
# [365]	validation_0-mae:6.32251	validation_1-mae:5.91497
# [366]	validation_0-mae:6.32236	validation_1-mae:5.91490
# [367]	validation_0-mae:6.32224	validation_1-mae:5.91488
# [368]	validation_0-mae:6.32207	validation_1-mae:5.91483
# [369]	validation_0-mae:6.32191	validation_1-mae:5.91476
# [370]	validation_0-mae:6.32182	validation_1-mae:5.91476
# [371]	validation_0-mae:6.32170	validation_1-mae:5.91473
# [372]	validation_0-mae:6.32159	validation_1-mae:5.91473
# [373]	validation_0-mae:6.32151	validation_1-mae:5.91472
# [374]	validation_0-mae:6.32136	validation_1-mae:5.91465
# [375]	validation_0-mae:6.32122	validation_1-mae:5.91458
# [376]	validation_0-mae:6.32111	validation_1-mae:5.91457
# [377]	validation_0-mae:6.32097	validation_1-mae:5.91451
# [378]	validation_0-mae:6.32085	validation_1-mae:5.91451
# [379]	validation_0-mae:6.32072	validation_1-mae:5.91446
# [380]	validation_0-mae:6.32060	validation_1-mae:5.91442
# [381]	validation_0-mae:6.32046	validation_1-mae:5.91437
# [382]	validation_0-mae:6.32023	validation_1-mae:5.91425
# [383]	validation_0-mae:6.32007	validation_1-mae:5.91415
# [384]	validation_0-mae:6.31987	validation_1-mae:5.91403
# [385]	validation_0-mae:6.31973	validation_1-mae:5.91399
# [386]	validation_0-mae:6.31957	validation_1-mae:5.91389
# [387]	validation_0-mae:6.31950	validation_1-mae:5.91388
# [388]	validation_0-mae:6.31934	validation_1-mae:5.91382
# [389]	validation_0-mae:6.31919	validation_1-mae:5.91375
# [390]	validation_0-mae:6.31899	validation_1-mae:5.91365
# [391]	validation_0-mae:6.31884	validation_1-mae:5.91358
# [392]	validation_0-mae:6.31870	validation_1-mae:5.91354
# [393]	validation_0-mae:6.31861	validation_1-mae:5.91351
# [394]	validation_0-mae:6.31854	validation_1-mae:5.91351
# [395]	validation_0-mae:6.31844	validation_1-mae:5.91347
# [396]	validation_0-mae:6.31832	validation_1-mae:5.91345
# [397]	validation_0-mae:6.31823	validation_1-mae:5.91342
# [398]	validation_0-mae:6.31813	validation_1-mae:5.91341
# [399]	validation_0-mae:6.31798	validation_1-mae:5.91330
# [400]	validation_0-mae:6.31782	validation_1-mae:5.91326
# [401]	validation_0-mae:6.31771	validation_1-mae:5.91325
# [402]	validation_0-mae:6.31762	validation_1-mae:5.91326
# [403]	validation_0-mae:6.31748	validation_1-mae:5.91315
# [404]	validation_0-mae:6.31736	validation_1-mae:5.91314
# [405]	validation_0-mae:6.31726	validation_1-mae:5.91312
# [406]	validation_0-mae:6.31715	validation_1-mae:5.91309
# [407]	validation_0-mae:6.31705	validation_1-mae:5.91305
# [408]	validation_0-mae:6.31697	validation_1-mae:5.91305
# [409]	validation_0-mae:6.31680	validation_1-mae:5.91296
# [410]	validation_0-mae:6.31668	validation_1-mae:5.91291
# [411]	validation_0-mae:6.31651	validation_1-mae:5.91282
# [412]	validation_0-mae:6.31638	validation_1-mae:5.91280
# [413]	validation_0-mae:6.31625	validation_1-mae:5.91277
# [414]	validation_0-mae:6.31614	validation_1-mae:5.91274
# [415]	validation_0-mae:6.31602	validation_1-mae:5.91273
# [416]	validation_0-mae:6.31586	validation_1-mae:5.91270
# [417]	validation_0-mae:6.31566	validation_1-mae:5.91262
# [418]	validation_0-mae:6.31550	validation_1-mae:5.91262
# [419]	validation_0-mae:6.31539	validation_1-mae:5.91259
# [420]	validation_0-mae:6.31531	validation_1-mae:5.91258
# [421]	validation_0-mae:6.31524	validation_1-mae:5.91257
# [422]	validation_0-mae:6.31514	validation_1-mae:5.91255
# [423]	validation_0-mae:6.31503	validation_1-mae:5.91251
# [424]	validation_0-mae:6.31491	validation_1-mae:5.91245
# [425]	validation_0-mae:6.31470	validation_1-mae:5.91234
# [426]	validation_0-mae:6.31455	validation_1-mae:5.91228
# [427]	validation_0-mae:6.31444	validation_1-mae:5.91229
# [428]	validation_0-mae:6.31435	validation_1-mae:5.91227
# [429]	validation_0-mae:6.31426	validation_1-mae:5.91224
# [430]	validation_0-mae:6.31414	validation_1-mae:5.91218
# [431]	validation_0-mae:6.31402	validation_1-mae:5.91211
# [432]	validation_0-mae:6.31389	validation_1-mae:5.91209
# [433]	validation_0-mae:6.31380	validation_1-mae:5.91209
# [434]	validation_0-mae:6.31368	validation_1-mae:5.91208
# [435]	validation_0-mae:6.31360	validation_1-mae:5.91207
# [436]	validation_0-mae:6.31348	validation_1-mae:5.91201
# [437]	validation_0-mae:6.31337	validation_1-mae:5.91198
# [438]	validation_0-mae:6.31327	validation_1-mae:5.91195
# [439]	validation_0-mae:6.31311	validation_1-mae:5.91188
# [440]	validation_0-mae:6.31302	validation_1-mae:5.91184
# [441]	validation_0-mae:6.31293	validation_1-mae:5.91182
# [442]	validation_0-mae:6.31273	validation_1-mae:5.91177
# [443]	validation_0-mae:6.31264	validation_1-mae:5.91178
# [444]	validation_0-mae:6.31256	validation_1-mae:5.91178
# [445]	validation_0-mae:6.31247	validation_1-mae:5.91175
# [446]	validation_0-mae:6.31233	validation_1-mae:5.91169
# [447]	validation_0-mae:6.31218	validation_1-mae:5.91162
# [448]	validation_0-mae:6.31210	validation_1-mae:5.91163
# [449]	validation_0-mae:6.31195	validation_1-mae:5.91156
# [450]	validation_0-mae:6.31180	validation_1-mae:5.91149
# [451]	validation_0-mae:6.31170	validation_1-mae:5.91146
# [452]	validation_0-mae:6.31150	validation_1-mae:5.91135
# [453]	validation_0-mae:6.31133	validation_1-mae:5.91129
# [454]	validation_0-mae:6.31119	validation_1-mae:5.91127
# [455]	validation_0-mae:6.31101	validation_1-mae:5.91116
# [456]	validation_0-mae:6.31091	validation_1-mae:5.91109
# [457]	validation_0-mae:6.31077	validation_1-mae:5.91103
# [458]	validation_0-mae:6.31068	validation_1-mae:5.91103
# [459]	validation_0-mae:6.31055	validation_1-mae:5.91101
# [460]	validation_0-mae:6.31037	validation_1-mae:5.91094
# [461]	validation_0-mae:6.31025	validation_1-mae:5.91090
# [462]	validation_0-mae:6.31011	validation_1-mae:5.91086
# [463]	validation_0-mae:6.30996	validation_1-mae:5.91080
# [464]	validation_0-mae:6.30988	validation_1-mae:5.91079
# [465]	validation_0-mae:6.30980	validation_1-mae:5.91078
# [466]	validation_0-mae:6.30967	validation_1-mae:5.91073
# [467]	validation_0-mae:6.30957	validation_1-mae:5.91071
# [468]	validation_0-mae:6.30943	validation_1-mae:5.91065
# [469]	validation_0-mae:6.30932	validation_1-mae:5.91066
# [470]	validation_0-mae:6.30925	validation_1-mae:5.91065
# [471]	validation_0-mae:6.30915	validation_1-mae:5.91063
# [472]	validation_0-mae:6.30902	validation_1-mae:5.91056
# [473]	validation_0-mae:6.30893	validation_1-mae:5.91056
# [474]	validation_0-mae:6.30869	validation_1-mae:5.91045
# [475]	validation_0-mae:6.30856	validation_1-mae:5.91038
# [476]	validation_0-mae:6.30848	validation_1-mae:5.91038
# [477]	validation_0-mae:6.30841	validation_1-mae:5.91038
# [478]	validation_0-mae:6.30830	validation_1-mae:5.91033
# [479]	validation_0-mae:6.30817	validation_1-mae:5.91028
# [480]	validation_0-mae:6.30806	validation_1-mae:5.91027
# [481]	validation_0-mae:6.30795	validation_1-mae:5.91021
# [482]	validation_0-mae:6.30787	validation_1-mae:5.91021
# [483]	validation_0-mae:6.30777	validation_1-mae:5.91019
# [484]	validation_0-mae:6.30767	validation_1-mae:5.91017
# [485]	validation_0-mae:6.30758	validation_1-mae:5.91014
# [486]	validation_0-mae:6.30737	validation_1-mae:5.91001
# [487]	validation_0-mae:6.30727	validation_1-mae:5.91000
# [488]	validation_0-mae:6.30711	validation_1-mae:5.90996
# [489]	validation_0-mae:6.30697	validation_1-mae:5.90987
# [490]	validation_0-mae:6.30685	validation_1-mae:5.90982
# [491]	validation_0-mae:6.30674	validation_1-mae:5.90981
# [492]	validation_0-mae:6.30665	validation_1-mae:5.90983
# [493]	validation_0-mae:6.30655	validation_1-mae:5.90979
# [494]	validation_0-mae:6.30644	validation_1-mae:5.90977
# [495]	validation_0-mae:6.30633	validation_1-mae:5.90976
# [496]	validation_0-mae:6.30615	validation_1-mae:5.90969
# [497]	validation_0-mae:6.30607	validation_1-mae:5.90970
# [498]	validation_0-mae:6.30599	validation_1-mae:5.90970
# [499]	validation_0-mae:6.30585	validation_1-mae:5.90968
# [500]	validation_0-mae:6.30573	validation_1-mae:5.90965
# [501]	validation_0-mae:6.30566	validation_1-mae:5.90966
# [502]	validation_0-mae:6.30554	validation_1-mae:5.90960
# [503]	validation_0-mae:6.30544	validation_1-mae:5.90958
# [504]	validation_0-mae:6.30535	validation_1-mae:5.90954
# [505]	validation_0-mae:6.30519	validation_1-mae:5.90946
# [506]	validation_0-mae:6.30504	validation_1-mae:5.90938
# [507]	validation_0-mae:6.30494	validation_1-mae:5.90938
# [508]	validation_0-mae:6.30480	validation_1-mae:5.90933
# [509]	validation_0-mae:6.30470	validation_1-mae:5.90931
# [510]	validation_0-mae:6.30455	validation_1-mae:5.90927
# [511]	validation_0-mae:6.30444	validation_1-mae:5.90926
# [512]	validation_0-mae:6.30430	validation_1-mae:5.90918
# [513]	validation_0-mae:6.30422	validation_1-mae:5.90917
# [514]	validation_0-mae:6.30414	validation_1-mae:5.90917
# [515]	validation_0-mae:6.30404	validation_1-mae:5.90913
# [516]	validation_0-mae:6.30396	validation_1-mae:5.90914
# [517]	validation_0-mae:6.30388	validation_1-mae:5.90914
# [518]	validation_0-mae:6.30379	validation_1-mae:5.90914
# [519]	validation_0-mae:6.30370	validation_1-mae:5.90914
# [520]	validation_0-mae:6.30357	validation_1-mae:5.90910
# [521]	validation_0-mae:6.30338	validation_1-mae:5.90899
# [522]	validation_0-mae:6.30317	validation_1-mae:5.90892
# [523]	validation_0-mae:6.30306	validation_1-mae:5.90891
# [524]	validation_0-mae:6.30293	validation_1-mae:5.90882
# [525]	validation_0-mae:6.30284	validation_1-mae:5.90879
# [526]	validation_0-mae:6.30275	validation_1-mae:5.90877
# [527]	validation_0-mae:6.30264	validation_1-mae:5.90872
# [528]	validation_0-mae:6.30255	validation_1-mae:5.90868
# [529]	validation_0-mae:6.30246	validation_1-mae:5.90869
# [530]	validation_0-mae:6.30239	validation_1-mae:5.90870
# [531]	validation_0-mae:6.30228	validation_1-mae:5.90867
# [532]	validation_0-mae:6.30223	validation_1-mae:5.90867
# [533]	validation_0-mae:6.30203	validation_1-mae:5.90857
# [534]	validation_0-mae:6.30191	validation_1-mae:5.90852
# [535]	validation_0-mae:6.30181	validation_1-mae:5.90853
# [536]	validation_0-mae:6.30171	validation_1-mae:5.90851
# [537]	validation_0-mae:6.30164	validation_1-mae:5.90850
# [538]	validation_0-mae:6.30153	validation_1-mae:5.90849
# [539]	validation_0-mae:6.30146	validation_1-mae:5.90847
# [540]	validation_0-mae:6.30137	validation_1-mae:5.90846
# [541]	validation_0-mae:6.30129	validation_1-mae:5.90845
# [542]	validation_0-mae:6.30120	validation_1-mae:5.90848
# [543]	validation_0-mae:6.30106	validation_1-mae:5.90845
# [544]	validation_0-mae:6.30096	validation_1-mae:5.90843
# [545]	validation_0-mae:6.30088	validation_1-mae:5.90842
# [546]	validation_0-mae:6.30076	validation_1-mae:5.90840
# [547]	validation_0-mae:6.30071	validation_1-mae:5.90841
# [548]	validation_0-mae:6.30055	validation_1-mae:5.90832
# [549]	validation_0-mae:6.30046	validation_1-mae:5.90833
# [550]	validation_0-mae:6.30037	validation_1-mae:5.90829
# [551]	validation_0-mae:6.30022	validation_1-mae:5.90820
# [552]	validation_0-mae:6.30013	validation_1-mae:5.90821
# [553]	validation_0-mae:6.30003	validation_1-mae:5.90821
# [554]	validation_0-mae:6.29993	validation_1-mae:5.90821
# [555]	validation_0-mae:6.29985	validation_1-mae:5.90821
# [556]	validation_0-mae:6.29976	validation_1-mae:5.90820
# [557]	validation_0-mae:6.29967	validation_1-mae:5.90819
# [558]	validation_0-mae:6.29953	validation_1-mae:5.90815
# [559]	validation_0-mae:6.29936	validation_1-mae:5.90805
# [560]	validation_0-mae:6.29926	validation_1-mae:5.90801
# [561]	validation_0-mae:6.29917	validation_1-mae:5.90801
# [562]	validation_0-mae:6.29909	validation_1-mae:5.90800
# [563]	validation_0-mae:6.29899	validation_1-mae:5.90801
# [564]	validation_0-mae:6.29887	validation_1-mae:5.90795
# [565]	validation_0-mae:6.29877	validation_1-mae:5.90791
# [566]	validation_0-mae:6.29868	validation_1-mae:5.90787
# [567]	validation_0-mae:6.29860	validation_1-mae:5.90786
# [568]	validation_0-mae:6.29853	validation_1-mae:5.90786
# [569]	validation_0-mae:6.29839	validation_1-mae:5.90783
# [570]	validation_0-mae:6.29831	validation_1-mae:5.90781
# [571]	validation_0-mae:6.29823	validation_1-mae:5.90781
# [572]	validation_0-mae:6.29815	validation_1-mae:5.90782
# [573]	validation_0-mae:6.29806	validation_1-mae:5.90780
# [574]	validation_0-mae:6.29801	validation_1-mae:5.90781
# [575]	validation_0-mae:6.29793	validation_1-mae:5.90784
# [576]	validation_0-mae:6.29786	validation_1-mae:5.90785
# [577]	validation_0-mae:6.29770	validation_1-mae:5.90782
# [578]	validation_0-mae:6.29755	validation_1-mae:5.90777
# [579]	validation_0-mae:6.29745	validation_1-mae:5.90773
# [580]	validation_0-mae:6.29737	validation_1-mae:5.90773
# [581]	validation_0-mae:6.29729	validation_1-mae:5.90772
# [582]	validation_0-mae:6.29714	validation_1-mae:5.90765
# [583]	validation_0-mae:6.29703	validation_1-mae:5.90759
# [584]	validation_0-mae:6.29694	validation_1-mae:5.90758
# [585]	validation_0-mae:6.29687	validation_1-mae:5.90755
# [586]	validation_0-mae:6.29679	validation_1-mae:5.90755
# [587]	validation_0-mae:6.29671	validation_1-mae:5.90755
# [588]	validation_0-mae:6.29660	validation_1-mae:5.90751
# [589]	validation_0-mae:6.29653	validation_1-mae:5.90751
# [590]	validation_0-mae:6.29644	validation_1-mae:5.90751
# [591]	validation_0-mae:6.29636	validation_1-mae:5.90749
# [592]	validation_0-mae:6.29624	validation_1-mae:5.90743
# [593]	validation_0-mae:6.29617	validation_1-mae:5.90743
# [594]	validation_0-mae:6.29607	validation_1-mae:5.90739
# [595]	validation_0-mae:6.29598	validation_1-mae:5.90739
# [596]	validation_0-mae:6.29588	validation_1-mae:5.90736
# [597]	validation_0-mae:6.29579	validation_1-mae:5.90733
# [598]	validation_0-mae:6.29565	validation_1-mae:5.90730
# [599]	validation_0-mae:6.29552	validation_1-mae:5.90725
# [600]	validation_0-mae:6.29542	validation_1-mae:5.90724
# [601]	validation_0-mae:6.29535	validation_1-mae:5.90723
# [602]	validation_0-mae:6.29528	validation_1-mae:5.90722
# [603]	validation_0-mae:6.29520	validation_1-mae:5.90721
# [604]	validation_0-mae:6.29501	validation_1-mae:5.90714
# [605]	validation_0-mae:6.29482	validation_1-mae:5.90707
# [606]	validation_0-mae:6.29476	validation_1-mae:5.90707
# [607]	validation_0-mae:6.29466	validation_1-mae:5.90706
# [608]	validation_0-mae:6.29456	validation_1-mae:5.90702
# [609]	validation_0-mae:6.29446	validation_1-mae:5.90699
# [610]	validation_0-mae:6.29440	validation_1-mae:5.90699
# [611]	validation_0-mae:6.29431	validation_1-mae:5.90695
# [612]	validation_0-mae:6.29423	validation_1-mae:5.90695
# [613]	validation_0-mae:6.29413	validation_1-mae:5.90692
# [614]	validation_0-mae:6.29404	validation_1-mae:5.90692
# [615]	validation_0-mae:6.29394	validation_1-mae:5.90688
# [616]	validation_0-mae:6.29384	validation_1-mae:5.90687
# [617]	validation_0-mae:6.29374	validation_1-mae:5.90687
# [618]	validation_0-mae:6.29365	validation_1-mae:5.90686
# [619]	validation_0-mae:6.29356	validation_1-mae:5.90684
# [620]	validation_0-mae:6.29347	validation_1-mae:5.90683
# [621]	validation_0-mae:6.29338	validation_1-mae:5.90684
# [622]	validation_0-mae:6.29329	validation_1-mae:5.90680
# [623]	validation_0-mae:6.29324	validation_1-mae:5.90680
# [624]	validation_0-mae:6.29316	validation_1-mae:5.90682
# [625]	validation_0-mae:6.29310	validation_1-mae:5.90682
# [626]	validation_0-mae:6.29303	validation_1-mae:5.90682
# [627]	validation_0-mae:6.29294	validation_1-mae:5.90681
# [628]	validation_0-mae:6.29284	validation_1-mae:5.90677
# [629]	validation_0-mae:6.29274	validation_1-mae:5.90673
# [630]	validation_0-mae:6.29266	validation_1-mae:5.90671
# [631]	validation_0-mae:6.29259	validation_1-mae:5.90670
# [632]	validation_0-mae:6.29251	validation_1-mae:5.90668
# [633]	validation_0-mae:6.29244	validation_1-mae:5.90667
# [634]	validation_0-mae:6.29236	validation_1-mae:5.90667
# [635]	validation_0-mae:6.29226	validation_1-mae:5.90666
# [636]	validation_0-mae:6.29210	validation_1-mae:5.90655
# [637]	validation_0-mae:6.29203	validation_1-mae:5.90654
# [638]	validation_0-mae:6.29196	validation_1-mae:5.90654
# [639]	validation_0-mae:6.29187	validation_1-mae:5.90658
# [640]	validation_0-mae:6.29180	validation_1-mae:5.90657
# [641]	validation_0-mae:6.29171	validation_1-mae:5.90659
# [642]	validation_0-mae:6.29165	validation_1-mae:5.90659
# [643]	validation_0-mae:6.29157	validation_1-mae:5.90658
# [644]	validation_0-mae:6.29145	validation_1-mae:5.90657
# [645]	validation_0-mae:6.29140	validation_1-mae:5.90660
# [646]	validation_0-mae:6.29131	validation_1-mae:5.90658
# [647]	validation_0-mae:6.29125	validation_1-mae:5.90659
# [648]	validation_0-mae:6.29118	validation_1-mae:5.90661
# [649]	validation_0-mae:6.29104	validation_1-mae:5.90654
# [650]	validation_0-mae:6.29094	validation_1-mae:5.90649
# [651]	validation_0-mae:6.29086	validation_1-mae:5.90648
# [652]	validation_0-mae:6.29076	validation_1-mae:5.90646
# [653]	validation_0-mae:6.29068	validation_1-mae:5.90646
# [654]	validation_0-mae:6.29055	validation_1-mae:5.90640
# [655]	validation_0-mae:6.29048	validation_1-mae:5.90640
# [656]	validation_0-mae:6.29041	validation_1-mae:5.90641
# [657]	validation_0-mae:6.29035	validation_1-mae:5.90641
# [658]	validation_0-mae:6.29027	validation_1-mae:5.90638
# [659]	validation_0-mae:6.29019	validation_1-mae:5.90637
# [660]	validation_0-mae:6.29009	validation_1-mae:5.90637
# [661]	validation_0-mae:6.28996	validation_1-mae:5.90630
# [662]	validation_0-mae:6.28986	validation_1-mae:5.90628
# [663]	validation_0-mae:6.28979	validation_1-mae:5.90627
# [664]	validation_0-mae:6.28964	validation_1-mae:5.90623
# [665]	validation_0-mae:6.28955	validation_1-mae:5.90624
# [666]	validation_0-mae:6.28947	validation_1-mae:5.90623
# [667]	validation_0-mae:6.28938	validation_1-mae:5.90624
# [668]	validation_0-mae:6.28932	validation_1-mae:5.90621
# [669]	validation_0-mae:6.28926	validation_1-mae:5.90623
# [670]	validation_0-mae:6.28918	validation_1-mae:5.90624
# [671]	validation_0-mae:6.28906	validation_1-mae:5.90623
# [672]	validation_0-mae:6.28900	validation_1-mae:5.90623
# [673]	validation_0-mae:6.28890	validation_1-mae:5.90620
# [674]	validation_0-mae:6.28880	validation_1-mae:5.90619
# [675]	validation_0-mae:6.28872	validation_1-mae:5.90616
# [676]	validation_0-mae:6.28863	validation_1-mae:5.90612
# [677]	validation_0-mae:6.28857	validation_1-mae:5.90613
# [678]	validation_0-mae:6.28849	validation_1-mae:5.90612
# [679]	validation_0-mae:6.28838	validation_1-mae:5.90605
# [680]	validation_0-mae:6.28831	validation_1-mae:5.90606
# [681]	validation_0-mae:6.28821	validation_1-mae:5.90605
# [682]	validation_0-mae:6.28811	validation_1-mae:5.90602
# [683]	validation_0-mae:6.28798	validation_1-mae:5.90598
# [684]	validation_0-mae:6.28789	validation_1-mae:5.90594
# [685]	validation_0-mae:6.28781	validation_1-mae:5.90593
# [686]	validation_0-mae:6.28769	validation_1-mae:5.90588
# [687]	validation_0-mae:6.28760	validation_1-mae:5.90583
# [688]	validation_0-mae:6.28751	validation_1-mae:5.90585
# [689]	validation_0-mae:6.28744	validation_1-mae:5.90585
# [690]	validation_0-mae:6.28736	validation_1-mae:5.90584
# [691]	validation_0-mae:6.28726	validation_1-mae:5.90579
# [692]	validation_0-mae:6.28717	validation_1-mae:5.90579
# [693]	validation_0-mae:6.28708	validation_1-mae:5.90580
# [694]	validation_0-mae:6.28701	validation_1-mae:5.90577
# [695]	validation_0-mae:6.28687	validation_1-mae:5.90569
# [696]	validation_0-mae:6.28677	validation_1-mae:5.90566
# [697]	validation_0-mae:6.28669	validation_1-mae:5.90565
# [698]	validation_0-mae:6.28660	validation_1-mae:5.90562
# [699]	validation_0-mae:6.28653	validation_1-mae:5.90562
# [700]	validation_0-mae:6.28646	validation_1-mae:5.90563
# [701]	validation_0-mae:6.28635	validation_1-mae:5.90559
# [702]	validation_0-mae:6.28630	validation_1-mae:5.90559
# [703]	validation_0-mae:6.28622	validation_1-mae:5.90559
# [704]	validation_0-mae:6.28611	validation_1-mae:5.90555
# [705]	validation_0-mae:6.28598	validation_1-mae:5.90552
# [706]	validation_0-mae:6.28592	validation_1-mae:5.90551
# [707]	validation_0-mae:6.28585	validation_1-mae:5.90550
# [708]	validation_0-mae:6.28579	validation_1-mae:5.90549
# [709]	validation_0-mae:6.28575	validation_1-mae:5.90551
# [710]	validation_0-mae:6.28569	validation_1-mae:5.90550
# [711]	validation_0-mae:6.28563	validation_1-mae:5.90549
# [712]	validation_0-mae:6.28556	validation_1-mae:5.90549
# [713]	validation_0-mae:6.28549	validation_1-mae:5.90549
# [714]	validation_0-mae:6.28538	validation_1-mae:5.90548
# [715]	validation_0-mae:6.28531	validation_1-mae:5.90547
# [716]	validation_0-mae:6.28517	validation_1-mae:5.90543
# [717]	validation_0-mae:6.28510	validation_1-mae:5.90544
# [718]	validation_0-mae:6.28502	validation_1-mae:5.90543
# [719]	validation_0-mae:6.28496	validation_1-mae:5.90545
# [720]	validation_0-mae:6.28486	validation_1-mae:5.90542
# [721]	validation_0-mae:6.28475	validation_1-mae:5.90540
# [722]	validation_0-mae:6.28469	validation_1-mae:5.90539
# [723]	validation_0-mae:6.28463	validation_1-mae:5.90538
# [724]	validation_0-mae:6.28457	validation_1-mae:5.90535
# [725]	validation_0-mae:6.28447	validation_1-mae:5.90533
# [726]	validation_0-mae:6.28437	validation_1-mae:5.90531
# [727]	validation_0-mae:6.28428	validation_1-mae:5.90531
# [728]	validation_0-mae:6.28422	validation_1-mae:5.90530
# [729]	validation_0-mae:6.28416	validation_1-mae:5.90531
# [730]	validation_0-mae:6.28411	validation_1-mae:5.90530
# [731]	validation_0-mae:6.28406	validation_1-mae:5.90530
# [732]	validation_0-mae:6.28398	validation_1-mae:5.90531
# [733]	validation_0-mae:6.28390	validation_1-mae:5.90529
# [734]	validation_0-mae:6.28383	validation_1-mae:5.90529
# [735]	validation_0-mae:6.28375	validation_1-mae:5.90528
# [736]	validation_0-mae:6.28366	validation_1-mae:5.90525
# [737]	validation_0-mae:6.28355	validation_1-mae:5.90524
# [738]	validation_0-mae:6.28346	validation_1-mae:5.90522
# [739]	validation_0-mae:6.28340	validation_1-mae:5.90522
# [740]	validation_0-mae:6.28332	validation_1-mae:5.90520
# [741]	validation_0-mae:6.28325	validation_1-mae:5.90521
# [742]	validation_0-mae:6.28320	validation_1-mae:5.90520
# [743]	validation_0-mae:6.28311	validation_1-mae:5.90520
# [744]	validation_0-mae:6.28299	validation_1-mae:5.90517
# [745]	validation_0-mae:6.28292	validation_1-mae:5.90517
# [746]	validation_0-mae:6.28282	validation_1-mae:5.90516
# [747]	validation_0-mae:6.28271	validation_1-mae:5.90509
# [748]	validation_0-mae:6.28261	validation_1-mae:5.90508
# [749]	validation_0-mae:6.28254	validation_1-mae:5.90508
# [750]	validation_0-mae:6.28245	validation_1-mae:5.90504
# [751]	validation_0-mae:6.28238	validation_1-mae:5.90504
# [752]	validation_0-mae:6.28231	validation_1-mae:5.90503
# [753]	validation_0-mae:6.28222	validation_1-mae:5.90500
# [754]	validation_0-mae:6.28213	validation_1-mae:5.90496
# [755]	validation_0-mae:6.28205	validation_1-mae:5.90491
# [756]	validation_0-mae:6.28201	validation_1-mae:5.90492
# [757]	validation_0-mae:6.28196	validation_1-mae:5.90492
# [758]	validation_0-mae:6.28186	validation_1-mae:5.90487
# [759]	validation_0-mae:6.28177	validation_1-mae:5.90485
# [760]	validation_0-mae:6.28166	validation_1-mae:5.90485
# [761]	validation_0-mae:6.28158	validation_1-mae:5.90483
# [762]	validation_0-mae:6.28152	validation_1-mae:5.90483
# [763]	validation_0-mae:6.28145	validation_1-mae:5.90483
# [764]	validation_0-mae:6.28139	validation_1-mae:5.90482
# [765]	validation_0-mae:6.28127	validation_1-mae:5.90482
# [766]	validation_0-mae:6.28121	validation_1-mae:5.90482
# [767]	validation_0-mae:6.28112	validation_1-mae:5.90479
# [768]	validation_0-mae:6.28106	validation_1-mae:5.90479
# [769]	validation_0-mae:6.28099	validation_1-mae:5.90478
# [770]	validation_0-mae:6.28090	validation_1-mae:5.90479
# [771]	validation_0-mae:6.28079	validation_1-mae:5.90480
# [772]	validation_0-mae:6.28074	validation_1-mae:5.90482
# [773]	validation_0-mae:6.28070	validation_1-mae:5.90482
# [774]	validation_0-mae:6.28063	validation_1-mae:5.90482
# [775]	validation_0-mae:6.28057	validation_1-mae:5.90483
# [776]	validation_0-mae:6.28050	validation_1-mae:5.90485
# [777]	validation_0-mae:6.28042	validation_1-mae:5.90487
# [778]	validation_0-mae:6.28028	validation_1-mae:5.90483
# [779]	validation_0-mae:6.28021	validation_1-mae:5.90480
# [780]	validation_0-mae:6.28014	validation_1-mae:5.90478
# [781]	validation_0-mae:6.28007	validation_1-mae:5.90476
# [782]	validation_0-mae:6.28000	validation_1-mae:5.90476
# [783]	validation_0-mae:6.27994	validation_1-mae:5.90477
# [784]	validation_0-mae:6.27987	validation_1-mae:5.90477
# [785]	validation_0-mae:6.27980	validation_1-mae:5.90474
# [786]	validation_0-mae:6.27969	validation_1-mae:5.90470
# [787]	validation_0-mae:6.27964	validation_1-mae:5.90470
# [788]	validation_0-mae:6.27957	validation_1-mae:5.90470
# [789]	validation_0-mae:6.27950	validation_1-mae:5.90468
# [790]	validation_0-mae:6.27942	validation_1-mae:5.90465
# [791]	validation_0-mae:6.27936	validation_1-mae:5.90466
# [792]	validation_0-mae:6.27927	validation_1-mae:5.90466
# [793]	validation_0-mae:6.27923	validation_1-mae:5.90465
# [794]	validation_0-mae:6.27915	validation_1-mae:5.90465
# [795]	validation_0-mae:6.27905	validation_1-mae:5.90463
# [796]	validation_0-mae:6.27897	validation_1-mae:5.90464
# [797]	validation_0-mae:6.27890	validation_1-mae:5.90465
# [798]	validation_0-mae:6.27883	validation_1-mae:5.90464
# [799]	validation_0-mae:6.27875	validation_1-mae:5.90463
# [800]	validation_0-mae:6.27866	validation_1-mae:5.90462
# [801]	validation_0-mae:6.27862	validation_1-mae:5.90462
# [802]	validation_0-mae:6.27851	validation_1-mae:5.90459
# [803]	validation_0-mae:6.27837	validation_1-mae:5.90458
# [804]	validation_0-mae:6.27829	validation_1-mae:5.90458
# [805]	validation_0-mae:6.27822	validation_1-mae:5.90457
# [806]	validation_0-mae:6.27810	validation_1-mae:5.90456
# [807]	validation_0-mae:6.27802	validation_1-mae:5.90456
# [808]	validation_0-mae:6.27792	validation_1-mae:5.90454
# [809]	validation_0-mae:6.27784	validation_1-mae:5.90452
# [810]	validation_0-mae:6.27779	validation_1-mae:5.90452
# [811]	validation_0-mae:6.27775	validation_1-mae:5.90453
# [812]	validation_0-mae:6.27767	validation_1-mae:5.90455
# [813]	validation_0-mae:6.27760	validation_1-mae:5.90455
# [814]	validation_0-mae:6.27752	validation_1-mae:5.90455
# [815]	validation_0-mae:6.27740	validation_1-mae:5.90448
# [816]	validation_0-mae:6.27734	validation_1-mae:5.90448
# [817]	validation_0-mae:6.27726	validation_1-mae:5.90448
# [818]	validation_0-mae:6.27719	validation_1-mae:5.90450
# [819]	validation_0-mae:6.27709	validation_1-mae:5.90445
# [820]	validation_0-mae:6.27703	validation_1-mae:5.90445
# [821]	validation_0-mae:6.27695	validation_1-mae:5.90445
# [822]	validation_0-mae:6.27685	validation_1-mae:5.90446
# [823]	validation_0-mae:6.27677	validation_1-mae:5.90444
# [824]	validation_0-mae:6.27673	validation_1-mae:5.90444
# [825]	validation_0-mae:6.27666	validation_1-mae:5.90444
# [826]	validation_0-mae:6.27659	validation_1-mae:5.90444
# [827]	validation_0-mae:6.27654	validation_1-mae:5.90444
# [828]	validation_0-mae:6.27648	validation_1-mae:5.90443
# [829]	validation_0-mae:6.27643	validation_1-mae:5.90443
# [830]	validation_0-mae:6.27634	validation_1-mae:5.90440
# [831]	validation_0-mae:6.27629	validation_1-mae:5.90441
# [832]	validation_0-mae:6.27623	validation_1-mae:5.90440
# [833]	validation_0-mae:6.27618	validation_1-mae:5.90443
# [834]	validation_0-mae:6.27609	validation_1-mae:5.90443
# [835]	validation_0-mae:6.27601	validation_1-mae:5.90443
# [836]	validation_0-mae:6.27594	validation_1-mae:5.90443
# [837]	validation_0-mae:6.27585	validation_1-mae:5.90441
# [838]	validation_0-mae:6.27578	validation_1-mae:5.90442
# [839]	validation_0-mae:6.27570	validation_1-mae:5.90445
# [840]	validation_0-mae:6.27562	validation_1-mae:5.90443
# [841]	validation_0-mae:6.27556	validation_1-mae:5.90442
# [842]	validation_0-mae:6.27549	validation_1-mae:5.90445
# [843]	validation_0-mae:6.27542	validation_1-mae:5.90445
# [844]	validation_0-mae:6.27531	validation_1-mae:5.90439
# [845]	validation_0-mae:6.27524	validation_1-mae:5.90437
# [846]	validation_0-mae:6.27517	validation_1-mae:5.90439
# [847]	validation_0-mae:6.27510	validation_1-mae:5.90437
# [848]	validation_0-mae:6.27503	validation_1-mae:5.90436
# [849]	validation_0-mae:6.27496	validation_1-mae:5.90436
# [850]	validation_0-mae:6.27491	validation_1-mae:5.90435
# [851]	validation_0-mae:6.27481	validation_1-mae:5.90432
# [852]	validation_0-mae:6.27475	validation_1-mae:5.90432
# [853]	validation_0-mae:6.27469	validation_1-mae:5.90434
# [854]	validation_0-mae:6.27462	validation_1-mae:5.90434
# [855]	validation_0-mae:6.27458	validation_1-mae:5.90434
# [856]	validation_0-mae:6.27451	validation_1-mae:5.90434
# [857]	validation_0-mae:6.27443	validation_1-mae:5.90431
# ...
# [1046]	validation_0-mae:6.26068	validation_1-mae:5.90360
# [1047]	validation_0-mae:6.26063	validation_1-mae:5.90361
# [1048]	validation_0-mae:6.26057	validation_1-mae:5.90363
# [1049]	validation_0-mae:6.26050	validation_1-mae:5.90362
# [1050]	validation_0-mae:6.26040	validation_1-mae:5.90359
# [1051]	validation_0-mae:6.26034	validation_1-mae:5.90357
# [1052]	validation_0-mae:6.26028	validation_1-mae:5.90356
# [1053]	validation_0-mae:6.26022	validation_1-mae:5.90358
# [1054]	validation_0-mae:6.26016	validation_1-mae:5.90361
# [1055]	validation_0-mae:6.26010	validation_1-mae:5.90363
# [1056]	validation_0-mae:6.26004	validation_1-mae:5.90363
# [1057]	validation_0-mae:6.25995	validation_1-mae:5.90363
# [1058]	validation_0-mae:6.25989	validation_1-mae:5.90366
# [1059]	validation_0-mae:6.25983	validation_1-mae:5.90367
# [1060]	validation_0-mae:6.25977	validation_1-mae:5.90367
# [1061]	validation_0-mae:6.25972	validation_1-mae:5.90366
# [1062]	validation_0-mae:6.25964	validation_1-mae:5.90365
# [1063]	validation_0-mae:6.25958	validation_1-mae:5.90366
# [1064]	validation_0-mae:6.25951	validation_1-mae:5.90366
# [1065]	validation_0-mae:6.25942	validation_1-mae:5.90362
# [1066]	validation_0-mae:6.25937	validation_1-mae:5.90362
# [1067]	validation_0-mae:6.25929	validation_1-mae:5.90361
# [1068]	validation_0-mae:6.25923	validation_1-mae:5.90360
# [1069]	validation_0-mae:6.25916	validation_1-mae:5.90359
# [1070]	validation_0-mae:6.25911	validation_1-mae:5.90358
# [1071]	validation_0-mae:6.25906	validation_1-mae:5.90358
# [1072]	validation_0-mae:6.25898	validation_1-mae:5.90356
# [1073]	validation_0-mae:6.25891	validation_1-mae:5.90357
# [1074]	validation_0-mae:6.25886	validation_1-mae:5.90358
# [1075]	validation_0-mae:6.25879	validation_1-mae:5.90357
# [1076]	validation_0-mae:6.25873	validation_1-mae:5.90356
# [1077]	validation_0-mae:6.25869	validation_1-mae:5.90356
# [1078]	validation_0-mae:6.25863	validation_1-mae:5.90356
# [1079]	validation_0-mae:6.25858	validation_1-mae:5.90355
# [1080]	validation_0-mae:6.25854	validation_1-mae:5.90356
# [1081]	validation_0-mae:6.25848	validation_1-mae:5.90356
# [1082]	validation_0-mae:6.25843	validation_1-mae:5.90355
# [1083]	validation_0-mae:6.25835	validation_1-mae:5.90352
# [1084]	validation_0-mae:6.25829	validation_1-mae:5.90354
# [1085]	validation_0-mae:6.25824	validation_1-mae:5.90353
# [1086]	validation_0-mae:6.25817	validation_1-mae:5.90351
# [1087]	validation_0-mae:6.25811	validation_1-mae:5.90350
# [1088]	validation_0-mae:6.25806	validation_1-mae:5.90349
# [1089]	validation_0-mae:6.25801	validation_1-mae:5.90350
# [1090]	validation_0-mae:6.25796	validation_1-mae:5.90351
# [1091]	validation_0-mae:6.25790	validation_1-mae:5.90352
# [1092]	validation_0-mae:6.25785	validation_1-mae:5.90351
# [1093]	validation_0-mae:6.25779	validation_1-mae:5.90351
# [1094]	validation_0-mae:6.25772	validation_1-mae:5.90350
# [1095]	validation_0-mae:6.25767	validation_1-mae:5.90349
# [1096]	validation_0-mae:6.25759	validation_1-mae:5.90347
# [1097]	validation_0-mae:6.25754	validation_1-mae:5.90350
# [1098]	validation_0-mae:6.25747	validation_1-mae:5.90351
# [1099]	validation_0-mae:6.25740	validation_1-mae:5.90351
# [1100]	validation_0-mae:6.25731	validation_1-mae:5.90348
# [1101]	validation_0-mae:6.25727	validation_1-mae:5.90349
# [1102]	validation_0-mae:6.25724	validation_1-mae:5.90348
# [1103]	validation_0-mae:6.25717	validation_1-mae:5.90349
# [1104]	validation_0-mae:6.25708	validation_1-mae:5.90348
# [1105]	validation_0-mae:6.25702	validation_1-mae:5.90350
# [1106]	validation_0-mae:6.25694	validation_1-mae:5.90347
# [1107]	validation_0-mae:6.25688	validation_1-mae:5.90347
# [1108]	validation_0-mae:6.25682	validation_1-mae:5.90347
# [1109]	validation_0-mae:6.25677	validation_1-mae:5.90349
# [1110]	validation_0-mae:6.25670	validation_1-mae:5.90349
# [1111]	validation_0-mae:6.25660	validation_1-mae:5.90347
# [1112]	validation_0-mae:6.25652	validation_1-mae:5.90348
# [1113]	validation_0-mae:6.25646	validation_1-mae:5.90348
# [1114]	validation_0-mae:6.25638	validation_1-mae:5.90348
# [1115]	validation_0-mae:6.25634	validation_1-mae:5.90349
# [1116]	validation_0-mae:6.25627	validation_1-mae:5.90350
# [1117]	validation_0-mae:6.25620	validation_1-mae:5.90349
# [1118]	validation_0-mae:6.25615	validation_1-mae:5.90349
# [1119]	validation_0-mae:6.25609	validation_1-mae:5.90349
# [1120]	validation_0-mae:6.25603	validation_1-mae:5.90349
# [1121]	validation_0-mae:6.25598	validation_1-mae:5.90349
# [1122]	validation_0-mae:6.25593	validation_1-mae:5.90351
# [1123]	validation_0-mae:6.25588	validation_1-mae:5.90351
# [1124]	validation_0-mae:6.25581	validation_1-mae:5.90352
# [1125]	validation_0-mae:6.25576	validation_1-mae:5.90353
# [1126]	validation_0-mae:6.25568	validation_1-mae:5.90353
# [1127]	validation_0-mae:6.25562	validation_1-mae:5.90354
# [1128]	validation_0-mae:6.25556	validation_1-mae:5.90353
# [1129]	validation_0-mae:6.25552	validation_1-mae:5.90353
# [1130]	validation_0-mae:6.25547	validation_1-mae:5.90353
# [1131]	validation_0-mae:6.25542	validation_1-mae:5.90354
# [1132]	validation_0-mae:6.25537	validation_1-mae:5.90353
# [1133]	validation_0-mae:6.25527	validation_1-mae:5.90353
# [1134]	validation_0-mae:6.25520	validation_1-mae:5.90353
# [1135]	validation_0-mae:6.25512	validation_1-mae:5.90352
# [1136]	validation_0-mae:6.25507	validation_1-mae:5.90351
# [1137]	validation_0-mae:6.25499	validation_1-mae:5.90351
# [1138]	validation_0-mae:6.25494	validation_1-mae:5.90351
# [1139]	validation_0-mae:6.25487	validation_1-mae:5.90352
# [1140]	validation_0-mae:6.25480	validation_1-mae:5.90353
# [1141]	validation_0-mae:6.25472	validation_1-mae:5.90354
# [1142]	validation_0-mae:6.25467	validation_1-mae:5.90354
# [1143]	validation_0-mae:6.25460	validation_1-mae:5.90354
# [1144]	validation_0-mae:6.25452	validation_1-mae:5.90353
# [1145]	validation_0-mae:6.25447	validation_1-mae:5.90351
# [1146]	validation_0-mae:6.25442	validation_1-mae:5.90351
# [1147]	validation_0-mae:6.25437	validation_1-mae:5.90350
# [1148]	validation_0-mae:6.25433	validation_1-mae:5.90351
# [1149]	validation_0-mae:6.25427	validation_1-mae:5.90351
# [1150]	validation_0-mae:6.25419	validation_1-mae:5.90350
# [1151]	validation_0-mae:6.25411	validation_1-mae:5.90350
# [1152]	validation_0-mae:6.25404	validation_1-mae:5.90350
# [1153]	validation_0-mae:6.25398	validation_1-mae:5.90348
# [1154]	validation_0-mae:6.25390	validation_1-mae:5.90346
# [1155]	validation_0-mae:6.25383	validation_1-mae:5.90345
# [1156]	validation_0-mae:6.25376	validation_1-mae:5.90344
# [1157]	validation_0-mae:6.25371	validation_1-mae:5.90344
# [1158]	validation_0-mae:6.25365	validation_1-mae:5.90345
# [1159]	validation_0-mae:6.25359	validation_1-mae:5.90346
# [1160]	validation_0-mae:6.25354	validation_1-mae:5.90347
# [1161]	validation_0-mae:6.25348	validation_1-mae:5.90346
# [1162]	validation_0-mae:6.25341	validation_1-mae:5.90347
# [1163]	validation_0-mae:6.25334	validation_1-mae:5.90349
# [1164]	validation_0-mae:6.25328	validation_1-mae:5.90351
# [1165]	validation_0-mae:6.25322	validation_1-mae:5.90351
# [1166]	validation_0-mae:6.25314	validation_1-mae:5.90350
# [1167]	validation_0-mae:6.25309	validation_1-mae:5.90350
# [1168]	validation_0-mae:6.25303	validation_1-mae:5.90351
# [1169]	validation_0-mae:6.25298	validation_1-mae:5.90351
# [1170]	validation_0-mae:6.25291	validation_1-mae:5.90351
# [1171]	validation_0-mae:6.25286	validation_1-mae:5.90351
# [1172]	validation_0-mae:6.25282	validation_1-mae:5.90351
# [1173]	validation_0-mae:6.25275	validation_1-mae:5.90351
# [1174]	validation_0-mae:6.25270	validation_1-mae:5.90351
# [1175]	validation_0-mae:6.25264	validation_1-mae:5.90351
# [1176]	validation_0-mae:6.25257	validation_1-mae:5.90350
# [1177]	validation_0-mae:6.25250	validation_1-mae:5.90349
# [1178]	validation_0-mae:6.25245	validation_1-mae:5.90347
# [1179]	validation_0-mae:6.25238	validation_1-mae:5.90347
# [1180]	validation_0-mae:6.25230	validation_1-mae:5.90348
# [1181]	validation_0-mae:6.25219	validation_1-mae:5.90346
# [1182]	validation_0-mae:6.25209	validation_1-mae:5.90344
# [1183]	validation_0-mae:6.25205	validation_1-mae:5.90345
# [1184]	validation_0-mae:6.25200	validation_1-mae:5.90345
# [1185]	validation_0-mae:6.25194	validation_1-mae:5.90348
# [1186]	validation_0-mae:6.25184	validation_1-mae:5.90350
# [1187]	validation_0-mae:6.25178	validation_1-mae:5.90347
# [1188]	validation_0-mae:6.25172	validation_1-mae:5.90348
# [1189]	validation_0-mae:6.25167	validation_1-mae:5.90348
# [1190]	validation_0-mae:6.25161	validation_1-mae:5.90346
# [1191]	validation_0-mae:6.25154	validation_1-mae:5.90346
# [1192]	validation_0-mae:6.25146	validation_1-mae:5.90346
# [1193]	validation_0-mae:6.25142	validation_1-mae:5.90346
# [1194]	validation_0-mae:6.25138	validation_1-mae:5.90345
# [1195]	validation_0-mae:6.25134	validation_1-mae:5.90345
# [1196]	validation_0-mae:6.25127	validation_1-mae:5.90346
# [1197]	validation_0-mae:6.25122	validation_1-mae:5.90346
# [1198]	validation_0-mae:6.25118	validation_1-mae:5.90346
# [1199]	validation_0-mae:6.25111	validation_1-mae:5.90345
# [1200]	validation_0-mae:6.25106	validation_1-mae:5.90346
# [1201]	validation_0-mae:6.25100	validation_1-mae:5.90345
# [1202]	validation_0-mae:6.25096	validation_1-mae:5.90344
# [1203]	validation_0-mae:6.25090	validation_1-mae:5.90346
# [1204]	validation_0-mae:6.25082	validation_1-mae:5.90347
# [1205]	validation_0-mae:6.25077	validation_1-mae:5.90347
# [1206]	validation_0-mae:6.25069	validation_1-mae:5.90348
# [1207]	validation_0-mae:6.25063	validation_1-mae:5.90349
# [1208]	validation_0-mae:6.25056	validation_1-mae:5.90350
# [1209]	validation_0-mae:6.25050	validation_1-mae:5.90350
# [1210]	validation_0-mae:6.25046	validation_1-mae:5.90350
# [1211]	validation_0-mae:6.25040	validation_1-mae:5.90349
# [1212]	validation_0-mae:6.25034	validation_1-mae:5.90349
# [1213]	validation_0-mae:6.25026	validation_1-mae:5.90350
# [1214]	validation_0-mae:6.25019	validation_1-mae:5.90349
# [1215]	validation_0-mae:6.25010	validation_1-mae:5.90344
# [1216]	validation_0-mae:6.25006	validation_1-mae:5.90343
# [1217]	validation_0-mae:6.25002	validation_1-mae:5.90343
# [1218]	validation_0-mae:6.24994	validation_1-mae:5.90342
# [1219]	validation_0-mae:6.24987	validation_1-mae:5.90340
# [1220]	validation_0-mae:6.24980	validation_1-mae:5.90339
# [1221]	validation_0-mae:6.24975	validation_1-mae:5.90339
# [1222]	validation_0-mae:6.24966	validation_1-mae:5.90338
# [1223]	validation_0-mae:6.24959	validation_1-mae:5.90337
# [1224]	validation_0-mae:6.24951	validation_1-mae:5.90337
# [1225]	validation_0-mae:6.24941	validation_1-mae:5.90335
# [1226]	validation_0-mae:6.24933	validation_1-mae:5.90338
# [1227]	validation_0-mae:6.24928	validation_1-mae:5.90339
# [1228]	validation_0-mae:6.24924	validation_1-mae:5.90341
# [1229]	validation_0-mae:6.24917	validation_1-mae:5.90340
# [1230]	validation_0-mae:6.24910	validation_1-mae:5.90339
# [1231]	validation_0-mae:6.24905	validation_1-mae:5.90341
# [1232]	validation_0-mae:6.24900	validation_1-mae:5.90340
# [1233]	validation_0-mae:6.24894	validation_1-mae:5.90340
# [1234]	validation_0-mae:6.24891	validation_1-mae:5.90341
# [1235]	validation_0-mae:6.24885	validation_1-mae:5.90343
# [1236]	validation_0-mae:6.24874	validation_1-mae:5.90342
# [1237]	validation_0-mae:6.24868	validation_1-mae:5.90341
# [1238]	validation_0-mae:6.24863	validation_1-mae:5.90341
# [1239]	validation_0-mae:6.24856	validation_1-mae:5.90339
# [1240]	validation_0-mae:6.24853	validation_1-mae:5.90340
# [1241]	validation_0-mae:6.24845	validation_1-mae:5.90339
# [1242]	validation_0-mae:6.24841	validation_1-mae:5.90339
# [1243]	validation_0-mae:6.24836	validation_1-mae:5.90340
# [1244]	validation_0-mae:6.24833	validation_1-mae:5.90343
# [1245]	validation_0-mae:6.24828	validation_1-mae:5.90345
# [1246]	validation_0-mae:6.24824	validation_1-mae:5.90347
# [1247]	validation_0-mae:6.24819	validation_1-mae:5.90346
# [1248]	validation_0-mae:6.24812	validation_1-mae:5.90345
# [1249]	validation_0-mae:6.24807	validation_1-mae:5.90345
# [1250]	validation_0-mae:6.24801	validation_1-mae:5.90345
# [1251]	validation_0-mae:6.24795	validation_1-mae:5.90345
# [1252]	validation_0-mae:6.24790	validation_1-mae:5.90346
# [1253]	validation_0-mae:6.24784	validation_1-mae:5.90346
# [1254]	validation_0-mae:6.24777	validation_1-mae:5.90347
# [1255]	validation_0-mae:6.24771	validation_1-mae:5.90347
# [1256]	validation_0-mae:6.24763	validation_1-mae:5.90346
# [1257]	validation_0-mae:6.24756	validation_1-mae:5.90346
# [1258]	validation_0-mae:6.24751	validation_1-mae:5.90346
# [1259]	validation_0-mae:6.24746	validation_1-mae:5.90347
# [1260]	validation_0-mae:6.24742	validation_1-mae:5.90347
# [1261]	validation_0-mae:6.24739	validation_1-mae:5.90347
# [1262]	validation_0-mae:6.24734	validation_1-mae:5.90347
# [1263]	validation_0-mae:6.24728	validation_1-mae:5.90346
# [1264]	validation_0-mae:6.24721	validation_1-mae:5.90345
# [1265]	validation_0-mae:6.24713	validation_1-mae:5.90345
# [1266]	validation_0-mae:6.24708	validation_1-mae:5.90346
# [1267]	validation_0-mae:6.24703	validation_1-mae:5.90346
# [1268]	validation_0-mae:6.24696	validation_1-mae:5.90347
# [1269]	validation_0-mae:6.24690	validation_1-mae:5.90348
# [1270]	validation_0-mae:6.24681	validation_1-mae:5.90351
# [1271]	validation_0-mae:6.24676	validation_1-mae:5.90349
# [1272]	validation_0-mae:6.24671	validation_1-mae:5.90349
# [1273]	validation_0-mae:6.24667	validation_1-mae:5.90350
# [1274]	validation_0-mae:6.24661	validation_1-mae:5.90350
# [1275]	validation_0-mae:6.24655	validation_1-mae:5.90349
# [1276]	validation_0-mae:6.24644	validation_1-mae:5.90346
# [1277]	validation_0-mae:6.24637	validation_1-mae:5.90347
# [1278]	validation_0-mae:6.24630	validation_1-mae:5.90346
# [1279]	validation_0-mae:6.24625	validation_1-mae:5.90347
# [1280]	validation_0-mae:6.24620	validation_1-mae:5.90347
# [1281]	validation_0-mae:6.24615	validation_1-mae:5.90347
# [1282]	validation_0-mae:6.24611	validation_1-mae:5.90348
# [1283]	validation_0-mae:6.24607	validation_1-mae:5.90349
# [1284]	validation_0-mae:6.24600	validation_1-mae:5.90349
# [1285]	validation_0-mae:6.24595	validation_1-mae:5.90349
# [1286]	validation_0-mae:6.24591	validation_1-mae:5.90349
# [1287]	validation_0-mae:6.24584	validation_1-mae:5.90349
# [1288]	validation_0-mae:6.24577	validation_1-mae:5.90349
# [1289]	validation_0-mae:6.24571	validation_1-mae:5.90348
# [1290]	validation_0-mae:6.24566	validation_1-mae:5.90349
# [1291]	validation_0-mae:6.24560	validation_1-mae:5.90350
# [1292]	validation_0-mae:6.24556	validation_1-mae:5.90350
# [1293]	validation_0-mae:6.24550	validation_1-mae:5.90350
# [1294]	validation_0-mae:6.24545	validation_1-mae:5.90350
# [1295]	validation_0-mae:6.24539	validation_1-mae:5.90349
# [1296]	validation_0-mae:6.24531	validation_1-mae:5.90347
# [1297]	validation_0-mae:6.24525	validation_1-mae:5.90346
# [1298]	validation_0-mae:6.24520	validation_1-mae:5.90347
# [1299]	validation_0-mae:6.24514	validation_1-mae:5.90347
# [1300]	validation_0-mae:6.24508	validation_1-mae:5.90349
# [1301]	validation_0-mae:6.24502	validation_1-mae:5.90349
# [1302]	validation_0-mae:6.24496	validation_1-mae:5.90349
# [1303]	validation_0-mae:6.24491	validation_1-mae:5.90349
# [1304]	validation_0-mae:6.24487	validation_1-mae:5.90349
# [1305]	validation_0-mae:6.24477	validation_1-mae:5.90344
# [1306]	validation_0-mae:6.24472	validation_1-mae:5.90345
# [1307]	validation_0-mae:6.24467	validation_1-mae:5.90345
# [1308]	validation_0-mae:6.24463	validation_1-mae:5.90345
# [1309]	validation_0-mae:6.24457	validation_1-mae:5.90346
# [1310]	validation_0-mae:6.24450	validation_1-mae:5.90347
# [1311]	validation_0-mae:6.24443	validation_1-mae:5.90347
# [1312]	validation_0-mae:6.24436	validation_1-mae:5.90346
# [1313]	validation_0-mae:6.24432	validation_1-mae:5.90347
# [1314]	validation_0-mae:6.24427	validation_1-mae:5.90347
# [1315]	validation_0-mae:6.24423	validation_1-mae:5.90347
# [1316]	validation_0-mae:6.24418	validation_1-mae:5.90347
# [1317]	validation_0-mae:6.24412	validation_1-mae:5.90345
# [1318]	validation_0-mae:6.24406	validation_1-mae:5.90345
# [1319]	validation_0-mae:6.24399	validation_1-mae:5.90345
# [1320]	validation_0-mae:6.24393	validation_1-mae:5.90346
# [1321]	validation_0-mae:6.24386	validation_1-mae:5.90347
# [1322]	validation_0-mae:6.24381	validation_1-mae:5.90347
# [1323]	validation_0-mae:6.24374	validation_1-mae:5.90347
# [1324]	validation_0-mae:6.24366	validation_1-mae:5.90345
# [1325]	validation_0-mae:6.24362	validation_1-mae:5.90346
# Infer Model Training.

# %% [markdown]
# # Bringing some LightGBM models to the mix

# %%
import os
import lightgbm as lgb

def imbalance_features_lgbm(df):
    # Define lists of price and size-related column names
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("(ask_price + bid_price) / 2")
    df["liquidity_imbalance"] = df.eval("(bid_size-ask_size)/(bid_size+ask_size)")
    df["matched_imbalance"] = df.eval("(imbalance_size-matched_size)/(matched_size+imbalance_size)")
    df["size_imbalance"] = df.eval("bid_size / ask_size")

    for c in combinations(prices, 2):
        df[f"{c[0]}_{c[1]}_imb"] = df.eval(f"({c[0]} - {c[1]})/({c[0]} + {c[1]})")

    for c in [['ask_price', 'bid_price', 'wap', 'reference_price'], sizes]:
        triplet_feature = calculate_triplet_imbalance_numba(c, df)
        df[triplet_feature.columns] = triplet_feature.values
   
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['market_urgency'] = df['price_spread'] * df['liquidity_imbalance']
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    
    # Calculate various statistical aggregation features
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)
        

    for col in ['matched_size', 'imbalance_size', 'reference_price', 'imbalance_buy_sell_flag']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_shift_{window}"] = df.groupby('stock_id')[col].shift(window)
            df[f"{col}_ret_{window}"] = df.groupby('stock_id')[col].pct_change(window)
    
    # Calculate diff features for specific columns
    for col in ['ask_price', 'bid_price', 'ask_size', 'bid_size', 'market_urgency', 'imbalance_momentum', 'size_imbalance']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_diff_{window}"] = df.groupby("stock_id")[col].diff(window)
    return df.replace([np.inf, -np.inf], 0)

def other_features_lgbm(df):
    df["dow"] = df["date_id"] % 5  # Day of the week
    df["seconds"] = df["seconds_in_bucket"] % 60  
    df["minute"] = df["seconds_in_bucket"] // 60  
    for key, value in global_stock_id_feats.items():
        df[f"global_{key}"] = df["stock_id"].map(value.to_dict())

    return df

def generate_all_features_lgbm(df):
    # Select relevant columns for feature generation
    cols = [c for c in df.columns if c not in ["row_id", "time_id", "target"]]
    df = df[cols]
    # Generate imbalance features
    df = imbalance_features_lgbm(df)
    df = other_features_lgbm(df)
    gc.collect()  
    feature_name = [i for i in df.columns if i not in ["row_id", "target", "time_id", "date_id"]]
    return df[feature_name]

model_save_path = '/kaggle/input/lightgbm-models/modelitos_para_despues'
num_folds = 5  # The number of folds you used during training

loaded_models = [infer_model]

# Load each model
for i in range(1, num_folds + 1):
    model_filename = os.path.join(model_save_path, f'doblez_{i}.txt')
    if os.path.exists(model_filename):
        loaded_model = lgb.Booster(model_file=model_filename)
        loaded_models.append(loaded_model)
        print(f"Model for fold {i} loaded from {model_filename}")
    else:
        print(f"Model file {model_filename} not found.")

# Load the final model
final_model_filename = os.path.join(model_save_path, 'doblez-conjunto.txt')
if os.path.exists(final_model_filename):
    final_model = lgb.Booster(model_file=final_model_filename)
    loaded_models.append(final_model)
    print(f"Final model loaded from {final_model_filename}")
else:
    print(f"Final model file {final_model_filename} not found.")

# Now 'loaded_models' contains the models loaded from the files
# Out:
# Model for fold 1 loaded from /kaggle/input/lightgbm-models/modelitos_para_despues/doblez_1.txt
# Model for fold 2 loaded from /kaggle/input/lightgbm-models/modelitos_para_despues/doblez_2.txt
# Model for fold 3 loaded from /kaggle/input/lightgbm-models/modelitos_para_despues/doblez_3.txt
# Model for fold 4 loaded from /kaggle/input/lightgbm-models/modelitos_para_despues/doblez_4.txt
# Model for fold 5 loaded from /kaggle/input/lightgbm-models/modelitos_para_despues/doblez_5.txt
# Final model loaded from /kaggle/input/lightgbm-models/modelitos_para_despues/doblez-conjunto.txt

# %% [markdown]
# ### Inference and Submission with XGBoost
#
# **Explanation**
#
# The following code block is specifically tailored for generating predictions in the inference mode and subsequently submitting these predictions to the Optiver 2023 competition platform.
#
# 1. **Zero-Sum Function (`def zero_sum(prices, volumes):`)**
#    - This function accepts two NumPy arrays: `prices` representing price predictions, and `volumes` representing trade volumes.
#    - It calculates the standard error (`std_error`) by taking the square root of `volumes`.
#    - It computes a scaling factor `step` by dividing the total of `prices` by the cumulative sum of `std_error`.
#    - The function adjusts the `prices` using the calculated `step` and `std_error`, producing an output array `out` that ensures a zero-sum constraint.
#    - The `out` array is then returned, providing the adjusted price predictions.
#
# 2. **Inference Mode Check (`if is_infer:`)**
#    - This conditional block is triggered if the `is_infer` variable is set to `True`, signaling that the model is operating in inference mode.
#
# 3. **Competition Environment Setup**
#    - The `optiver2023` module is imported to interact with the competition environment.
#    - An environment object (`env`) is instantiated for interfacing with the Optiver 2023 competition's data and submission system.
#
# 4. **Variable Initialization**
#    - Key variables for processing the test data are initialized, including an iterator (`iter_test`), a count variable (`counter`), and bounds for the predictions (`y_min` and `y_max`).
#
# 5. **Data Preparation**
#    - Lists to track queries per second (`qps`) and a DataFrame (`cache`) for holding test data are set up.
#
# 6. **Test Data Iteration**
#    - The code enters a loop, processing the test data batches as provided by the competition environment.
#
# 7. **Loop Operations**
#    - Current time (`now_time`) is logged for performance tracking.
#    - Incoming test data is appended to the `cache`, maintaining a rolling window of the most recent entries.
#    - The `generate_all_features` function is called to extract predictive features from the test data.
#
# 8. **Prediction Generation**
#    - Predictions are made using the XGBoost model (`infer_model`) trained earlier.
#
# 9. **Prediction Adjustment**
#    - The `zero_sum` function is applied to the predictions, ensuring compliance with the zero-sum constraint of the competition.
#
# 10. **Prediction Clipping**
#    - Predictions are clipped to the predefined bounds (`y_min` and `y_max`) to meet competition rules.
#
# 11. **Prediction Submission Preparation**
#    - The sample submission is updated with the clipped prediction values.
#
# 12. **Prediction Submission**
#    - The updated predictions are submitted through the competition environment's `env.predict()` method.
#
# 13. **Performance Monitoring**
#    - The `counter` is incremented, and processing speed (`qps`) is calculated for each batch of predictions.
#
# 14. **Performance Reporting**
#    - Iteration count and average queries per second are reported periodically to monitor and adjust the inference process.
#
# 15. **Completion Time Estimation**
#    - Upon completion of the test data processing, the average qps is used to estimate and report the total time taken for inference.
#
# This code has been configured for the purpose of executing predictions within the Optiver 2023 trading challenge, utilizing an XGBoost model for inference. It integrates a specific transformation procedure (`zero_sum`) and enforces a prediction range prior to submitting these predictions to the competition's evaluation system.

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np
import pandas as pd
import time

def zero_sum(prices, volumes):
    std_error = np.sqrt(volumes)
    step = np.sum(prices) / np.sum(std_error)
    out = prices - std_error * step
    return out

# Inference
if is_infer:
    import optiver2023
    env = optiver2023.make_env()  # Setting up the environment for the competition
    iter_test = env.iter_test()   # Getting the iterator for the test set
    counter = 0                   # Initializing a counter
    y_min, y_max = -64, 64        # Setting prediction boundaries
    qps = []                      # Queries per second tracking
    cache = pd.DataFrame()        # Initializing a cache to store test data
    
    model_weights = [1/len(loaded_models)] * len(loaded_models)
    
    for (test_df, revealed_targets, sample_prediction_df) in iter_test:
        now_time = time.time()    # Current time for performance measurement
        print('counter:', counter)
        # Concatenating new test data with the cache, keeping only the last 21 observations per stock_id
        cache = pd.concat([cache, test_df], ignore_index=True, axis=0)
        if counter > 0:
            cache = cache.groupby('stock_id').tail(21).reset_index(drop=True)
        
        # Generate features for the current test DataFrame
        feat = generate_all_features(cache)[-len(test_df):]  # Assuming generate_all_features is a predefined function
        
        # Make predictions using the trained XGBRegressor model
        pred = loaded_models[0].predict(feat) * model_weights[0]
        
        feat = generate_all_features_lgbm(cache)[-len(test_df):]

        # Generate predictions for each model and calculate the weighted average
        for model, weight in zip(loaded_models[1:], model_weights[1:]):
            pred += weight * model.predict(feat)
        
        # Apply your zero-sum and clipping operations
        pred = zero_sum(pred, test_df['bid_size'] + test_df['ask_size'])
        clipped_predictions = np.clip(pred, y_min, y_max)
        
        # Set the predictions in the sample_prediction_df
        sample_prediction_df['target'] = clipped_predictions
        
        # Use the environment to make predictions
        env.predict(sample_prediction_df)
        
        counter += 1
        qps.append(time.time() - now_time)
        
        if counter % 10 == 0:
            print(f"{counter} queries per second: {np.mean(qps)}")

    time_cost = 1.146 * np.mean(qps)
    print(f"The code will take approximately {np.round(time_cost, 2)} hours to reason about")
# Out:
# This version of the API is not optimized and should not be used to estimate the runtime of your code on the hidden test set.
# counter: 0
# counter: 1
# counter: 2
# counter: 3
# counter: 4
# counter: 5
# counter: 6
# counter: 7
# counter: 8
# counter: 9
# 10 queries per second: 2.291595196723938
# counter: 10
# counter: 11
# counter: 12
# counter: 13
# counter: 14
# counter: 15
# counter: 16
# counter: 17
# counter: 18
# counter: 19
# 20 queries per second: 2.5274160623550417
# counter: 20
# counter: 21
# counter: 22
# counter: 23
# counter: 24
# counter: 25
# counter: 26
# counter: 27
# counter: 28
# counter: 29
# 30 queries per second: 2.3409871260325112
# counter: 30
# counter: 31
# counter: 32
# counter: 33
# counter: 34
# counter: 35
# counter: 36
# counter: 37
# counter: 38
# counter: 39
# 40 queries per second: 2.037287247180939
# counter: 40
# counter: 41
# counter: 42
# counter: 43
# counter: 44
# counter: 45
# counter: 46
# counter: 47
# counter: 48
# counter: 49
# 50 queries per second: 1.8398727130889894
# counter: 50
# counter: 51
# counter: 52
# counter: 53
# counter: 54
# counter: 55
# counter: 56
# counter: 57
# counter: 58
# counter: 59
# 60 queries per second: 1.7644461433092753
# counter: 60
# counter: 61
# counter: 62
# counter: 63
# counter: 64
# counter: 65
# counter: 66
# counter: 67
# counter: 68
# counter: 69
# 70 queries per second: 1.8963816268103464
# counter: 70
# counter: 71
# counter: 72
# counter: 73
# counter: 74
# counter: 75
# counter: 76
# counter: 77
# counter: 78
# counter: 79
# 80 queries per second: 1.9841070234775544
# counter: 80
# counter: 81
# counter: 82
# counter: 83
# counter: 84
# counter: 85
# counter: 86
# counter: 87
# counter: 88
# counter: 89
# 90 queries per second: 1.90586293803321
# counter: 90
# counter: 91
# counter: 92
# counter: 93
# counter: 94
# counter: 95
# counter: 96
# counter: 97
# counter: 98
# counter: 99
# 100 queries per second: 1.8187368202209473
# counter: 100
# counter: 101
# counter: 102
# counter: 103
# counter: 104
# counter: 105
# counter: 106
# counter: 107
# counter: 108
# counter: 109
# 110 queries per second: 1.7483734954487193
# counter: 110
# counter: 111
# counter: 112
# counter: 113
# counter: 114
# counter: 115
# counter: 116
# counter: 117
# counter: 118
# counter: 119
# 120 queries per second: 1.7751524925231934
# counter: 120
# counter: 121
# counter: 122
# counter: 123
# counter: 124
# counter: 125
# counter: 126
# counter: 127
# counter: 128
# counter: 129
# 130 queries per second: 1.8568103551864623
# counter: 130
# counter: 131
# counter: 132
# counter: 133
# counter: 134
# counter: 135
# counter: 136
# counter: 137
# counter: 138
# counter: 139
# 140 queries per second: 1.8616160188402449
# counter: 140
# counter: 141
# counter: 142
# counter: 143
# counter: 144
# counter: 145
# counter: 146
# counter: 147
# counter: 148
# counter: 149
# 150 queries per second: 1.810072790781657
# counter: 150
# counter: 151
# counter: 152
# counter: 153
# counter: 154
# counter: 155
# counter: 156
# counter: 157
# counter: 158
# counter: 159
# 160 queries per second: 1.7616767123341561
# counter: 160
# counter: 161
# counter: 162
# counter: 163
# counter: 164
# The code will take approximately 1.99 hours to reason about
